# %%
import sys
from pathlib import Path


# Detect project root correctly:
# Notebook CWD = /project-root/notebooks → parent = /project-root
project_root = Path.cwd().parent
print("Detected project root:", project_root)

# Add project root to Python import path (so vector_pipeline can be imported cleanly)
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
    print("Added to sys.path.")
# Out:
# Detected project root: /home/viktoriia/Documents/ML/project-25-2-scrum-team-data

# %%
from vector_pipeline import settings 

# Update settings to absolute paths (fixing the notebooks-relative problem)
settings.DATA_PATH = project_root / "data" / "processed_product.pkl"
settings.CHROMA_DIR = project_root / "chroma_db"

print("DATA_PATH:", settings.DATA_PATH.resolve(), "-> exists:", settings.DATA_PATH.exists())
print("CHROMA_DIR:", settings.CHROMA_DIR.resolve())
# Out:
# DATA_PATH: /home/viktoriia/Documents/ML/project-25-2-scrum-team-data/data/processed_product.pkl -> exists: True
# CHROMA_DIR: /home/viktoriia/Documents/ML/project-25-2-scrum-team-data/chroma_db

# %%
from vector_pipeline.ingestion import build_or_load_vectorstore

print("Loading / building vectorstore...")
vs = build_or_load_vectorstore()
print("Vectorstore ready ✅")
# Out:
# Loading / building vectorstore...
# Loading existing Chroma DB from /home/viktoriia/Documents/ML/project-25-2-scrum-team-data/chroma_db ...
# Vectorstore loaded successfully.
# Vectorstore ready ✅

# %%
import json

def print_json(data):
    print(json.dumps(data, indent=2, ensure_ascii=False))

# %%
api_request = {
    "session_id": "S12345",
    "user_id": "U9001",
    "messages": [
        {"role": "user", "content": "Show me wireless headphones with noise cancelling"}
    ],
    "top_k": 4,
    "use_reranker": True
}

print("📥 Incoming API request:")
print_json(api_request)
# Out:
# 📥 Incoming API request:
# {
#   "session_id": "S12345",
#   "user_id": "U9001",
#   "messages": [
#     {
#       "role": "user",
#       "content": "Show me wireless headphones with noise cancelling"
#     }
#   ],
#   "top_k": 4,
#   "use_reranker": true
# }

# %%
from vector_pipeline.api_wrapper import run_chat

result = run_chat(
    messages = list(api_request["messages"]),
    k=api_request.get("top_k", 5),
    use_reranker=api_request.get("use_reranker", True)
)

api_response = {
    "status": "success",
    "session_id": api_request["session_id"],
    "user_id": api_request["user_id"],
    "answer": result["answer"],
    "messages": result["messages"],  # updated history
    "retrieved": result["retrieved"]
}

print("📤 API response:")
print_json(api_response)
# Out:
# Loading existing Chroma DB from /home/viktoriia/Documents/ML/project-25-2-scrum-team-data/chroma_db ...
# Vectorstore loaded successfully.
# 📤 API response:
# {
#   "status": "success",
#   "session_id": "S12345",
#   "user_id": "U9001",
#   "answer": "Use ONLY the following product information to answer the question.\nIf the answer is not in the context, say you don't know.\n\nCONTEXT:\nProduct Title: Hollyland Lark M1 Wireless Lavalier Microphone with Noise Cancellation, 656ft Transmission,8H Battery Life, Compact Wireless Lapel Mic for DSLR Cameras/iPhone/Android/Live Streaming- Light Purple\nCategories: Musical Instruments, Microphones & Accessories, Microphones, Wireless Microphones & Systems, Wireless Lavalier Microphones\n\n---\n\nFeatures: 【Noise Cancellation & CD-level Audio Quality】This professional microphone has a built-in noise reduction chip, more effectively identifying the original sound in noisy environments. Wireless Lavalier mic has omnidirectional sound reception technology and records every detail. 【Wide Compatibility】The upgraded wireless clip-on microphone has a 3 in 1 universal receiver. No need to replace multiple individual interfaces or interface cables.Compatible with iPhone, iPad, Android Phones, DSLR camera, Laptop, MacBook, GoPro, Camcorder, etc. 【8H Working Time& 328ft Audio Range】Wireless microphone transmitter has a built-in large-capacity rechargeable battery and low-power chip, providing more than 8 hours. Wireless lapel mic can record within 100 meters without obstacles. Ideal for indoor and outdoor long-distance high-fidelity recording. 【Dual-People Pickup】With the dual wireless microphone, The voices of multiple people can be recorded simultaneously. Bluetooth microphone wireless is suitable for interviewing, online conferencing, podcasting, vlogging, multi-person live broadcasts, etc. 【Replaceable windproof covers】Two types of microphone windproof covers for your choice. Foam Windproof is suitable for indoor use to reduce vocal blast sound. Furry Windproof microphone is ideal for outdoor use to filter excess wind noise better. Different windproof covers can meet creators' needs in various scenarios.\nDescription:\n\n---\n\nFeatures: 🎤Upgraded Head Microphone: wireless microphone headset with LED Display,it can be clearly displayed the frequency,volume and battery status.▶Up to 165 feet transmission range in an open areal.▶Support 40 sets to use at the same time.🔔Not Support Mobile phone/Macbook/Laptop. 🎤Professional Wireless Microphone Headset: Built-in condenser microphone, high sensitivity pickup and prevent howling, provide you with HD sound quality.▶Adopt the latest UHF wireless technology provides a stronger signal , reducing the possibility of interference from Bluetooth or WiFi. 🎤Compatible Devices and Application:The wireless mic compatible with Voice Amplifiers,Multimedia equipment,Speakers with Mic input jack.It's ideal for class teaching,lecture,conference,also a very pop fitness headset mic. 🎤Plug and Play Head Mic:It will automatically connect when power on. If it does not connect successfully, please reconnect as follows:1⃣ Turn off the receiver and transmitter. 2⃣Turn on the transmitter, blue light is on, long press “+ ” to blue light flash. 3⃣Turn on the receiver immediately (There is no need to wait for the transmitter's blue light to stop flashing) wait for the connection. 4⃣The blue lights of both transmitter and receiver stop flashing, means connection is successful. 🎤Battery& Warranty:Built-in 400mA lithium battery,charging 2 hours,last for 5hours.▶All of our product with one year warranty,no need to worry about quality, XIAOKOA after-sales team will provide you with\n\n---\n\nFeatures: Great 2.4GHz Band-2.4GHz wireless in-ear monitor system create your personal or team's monitor system. uncompressed wireless signal transmission, low noise and latency.Mono balanced XLR or mono unbalanced TS input.Provides smooth frequency response with any headphones. Less than 5ms Latency-Simultaneous broadcasts on 6 channels no-interference, Less than 5ms Latency,Up to 107 dB signal-to-noise ratio provides clear, detailed audio at any volume. High Resolution 24-bit/48kbps audio. Broad 20Hz-20KHz frequency response，Dy ...
#   "messages": [
#     {
#       "role": "user",
#       "content": "Show me wireless headphones with noise cancelling"
#     },
#     {
#       "role": "assistant",
#       "content": "Use ONLY the following product information to answer the question.\nIf the answer is not in the context, say you don't know.\n\nCONTEXT:\nProduct Title: Hollyland Lark M1 Wireless Lavalier Microphone with Noise Cancellation, 656ft Transmission,8H Battery Life, Compact Wireless Lapel Mic for DSLR Cameras/iPhone/Android/Live Streaming- Light Purple\nCategories: Musical Instruments, Microphones & Accessories, Microphones, Wireless Microphones & Systems, Wireless Lavalier Microphones\n\n---\n\nFeatures: 【Noise Cancellation & CD-level Audio Quality】This professional microphone has a built-in noise reduction chip, more effectively identifying the original sound in noisy environments. Wireless Lavalier mic has omnidirectional sound reception technology and records every detail. 【Wide Compatibility】The upgraded wireless clip-on microphone has a 3 in 1 universal receiver. No need to replace multiple individual interfaces or interface cables.Compatible with iPhone, iPad, Android Phones, DSLR camera, Laptop, MacBook, GoPro, Camcorder, etc. 【8H Working Time& 328ft Audio Range】Wireless microphone transmitter has a built-in large-capacity rechargeable battery and low-power chip, providing more than 8 hours. Wireless lapel mic can record within 100 meters without obstacles. Ideal for indoor and outdoor long-distance high-fidelity recording. 【Dual-People Pickup】With the dual wireless microphone, The voices of multiple people can be recorded simultaneously. Bluetooth microphone wireless is suitable for interviewing, online conferencing, podcasting, vlogging, multi-person live broadcasts, etc. 【Replaceable windproof covers】Two types of microphone windproof covers for your choice. Foam Windproof is suitable for indoor use to reduce vocal blast sound. Furry Windproof microphone is ideal for outdoor use to filter excess wind noise better. Different windproof covers can meet creators' needs in various scenarios.\nDescription:\n\n---\n\nFeatures: 🎤Upgraded Head Microphone: wireless microphone headset with LED Display,it can be clearly displayed the frequency,volume and battery status.▶Up to 165 feet transmission range in an open areal.▶Support 40 sets to use at the same time.🔔Not Support Mobile phone/Macbook/Laptop. 🎤Professional Wireless Microphone Headset: Built-in condenser microphone, high sensitivity pickup and prevent howling, provide you with HD sound quality.▶Adopt the latest UHF wireless technology provides a stronger signal , reducing the possibility of interference from Bluetooth or WiFi. 🎤Compatible Devices and Application:The wireless mic compatible with Voice Amplifiers,Multimedia equipment,Speakers with Mic input jack.It's ideal for class teaching,lecture,conference,also a very pop fitness headset mic. 🎤Plug and Play Head Mic:It will automatically connect when power on. If it does not connect successfully, please reconnect as follows:1⃣ Turn off the receiver and transmitter. 2⃣Turn on the transmitter, blue light is on, long press “+ ” to blue light flash. 3⃣Turn on the receiver immediately (There is no need to wait for the transmitter's blue light to stop flashing) wait for the connection. 4⃣The blue lights of both transmitter and receiver stop flashing, means connection is successful. 🎤Battery& Warranty:Built-in 400mA lithium battery,charging 2 hours,last for 5hours.▶All of our product with one year warranty,no need to worry about quality, XIAOKOA after-sales team will provide you with\n\n---\n\nFeatures: Great 2.4GHz Band-2.4GHz wireless in-ear monitor system create your personal or team's monitor system. uncompressed wireless signal transmission, low noise and latency.Mono balanced XLR or mono unbalanced TS input.Provides smooth frequency response with any headphones. Less than 5ms Latency-Simultaneous broadcasts on 6 channels no-interference, Less than 5ms Latency,Up to 107 dB signal-to-noise ratio provides clear, detailed audio at any volume. High Resolution 24-bit/48kbps audio. Broad 20Hz-20KHz frequency respon ...
#     }
#   ],
#   "retrieved": [
#     {
#       "metadata": {
#         "description": "Description: wireless lavalier microphone for PC,iPhone,iPad,Cameras",
#         "store": "HollyView",
#         "product_id": "B0BQHKDXMC",
#         "features": "Features: One Click Noise Cancellation: Hollyland Lark M1 features a cutting-edge DSP noise cancellation chip, which provides effective environmental noise cancellation, and makes your video voice clear and clean. Incredible Lightweight and Compact: Lark M1wireless lavalier microphone weights only 0.42oz/11.8g, lighter than 3pcs of A4 papers, None-feeling wear experience. 8H Long Battery Life: Providing 8 hours of continuous working time when fully charged. Each TX and RX have a USB-C port for direct charging while working at the same time, perfect for outside Interview Video Podcast Vlog and never need to worry about the battery life. 656ft Long Rang Wireless Transmission Range. Lark M1 lapel wireless microphone supports up to 650ft stable and reliable and high fidelity audio receiving working distance in open space, make you easily handle complex environments. Wide Compatibility. Lark M1 wireless lavalier mic works with all kinds of devices. Included a 3.5mm-TRS-to-TRS cable for all kinds of DSLR cameras, and a 3.5mm-TRS-to-TRRS cable for computers/phones with a 3.5mm port. (3.5mm-TRS-to-lightning cable for iPhone/iPad or 3.5mm-TRS-to-Type-C cable for Android phones was not included). Package Contains: Charging Case*1, Transmitter*2,Receiver*1,Furry Windshied*2,3.5TRS-TRS cable(for camera)*1, 3.5 TRS-TRRS cable(for Mobiles with 3.5mm audio jack)*1, User Manual*1, Warantly Card*1,USB-C charging cable*1,Storage Case*1.",
#         "product_title": "Product Title: Hollyland Lark M1 Wireless Lavalier Microphone with Noise Cancellation, 656ft Transmission,8H Battery Life, Compact Wireless Lapel Mic for DSLR Cameras/iPhone/Android/Live Streaming- Light Purple",
#         "color": "Light Purple",
#         "rating": 4.4,
#         "sub_categories": "Categories: Musical Instruments, Microphones & Accessories, Microphones, Wireless Microphones & Systems, Wireless Lavalier Microphones",
#         "price": 129.0,
#         "main_category": "Musical Instruments",
#         "details": "{'Item Weight': '0.42 ounces', 'Product Dimensions': '3.27 x 2.36 x 1.18 inches', 'Country of Origin': 'China', 'Item model number': 'Lark M1', 'Batteries': '4 Lithium Polymer batteries required. (included)', 'Best Sellers Rank': {'Musical Instruments': 136, 'Wireless Lavalier Microphones & Systems': 8}, 'Date First Available': 'November 1, 2022', 'Color Name': 'Light Purple', 'Compatible Devices': 'Personal Computer, Camera', 'Connector Type': 'USB, 3.5 mm Jack', 'Size': '2TX+1RX', 'Hardware Platform': 'PC, Tablet, Camera, Smartphone', 'Power Source': 'Battery Powered', 'Recommended Uses For Product': 'Streaming, Podcasting', 'Brand': 'HollyView', 'Model Name': 'Lark M1', 'Connectivity Technology': 'USB', 'Special Feature': 'Wireless, 3.5mm jack, USB, Lightweight', 'Color': 'Light Purple', 'Included Components': '2TX 1RX', 'Polar Pattern': 'Omnidirectional'}",
#         "rating_count": 1148
#       },
#       "snippet": "Product Title: Hollyland Lark M1 Wireless Lavalier Microphone with Noise Cancellation, 656ft Transmission,8H Battery Life, Compact Wireless Lapel Mic for DSLR Cameras/iPhone/Android/Live Streaming- Light Purple\nCategories: Musical Instruments, Microphones & Accessories, Microphones, Wireless Microphones & Systems, Wireless Lavalier Microphones"
#     },
#     {
#       "metadata": {
#         "rating": 4.4,
#         "features": "Features: 【Noise Cancellation & CD-level Audio Quality】This professional microphone has a built-in noise reduction chip, more effectively identifying the original sound in noisy environments. Wireless Lavalier mic has omnidirectional sound reception technology and records every detail. 【Wide Compatibility】The upgraded wireless clip-on microphone has a 3 in 1 universal receiver. No need to replace multiple individual interfaces or interface cables.Compatible with iPhone, iPad, Android Phones, DSLR camera, Laptop, MacBook, GoPro, Camcorder, etc. 【8H Working Time& 328ft Audio Range】Wireless microphone transmitter has a built-in large-capacity rechargeable battery and low-power chip, providing more than 8 hours. Wireless lapel mic can record within 100 meters without obstacles. Ideal for indoor and outdoor long-distance high-fidelity recording. 【Dual-People Pickup】With the dual wireless microphone, The voices of multiple people can be recorded simultaneously. Bluetooth microphone wireless is suitable for interviewing, online conferencing, podcasting, vlogging, multi-person live broadcasts, etc. 【Replaceable windproof covers】Two types of microphone windproof covers for your choice. Foam Windproof is suitable for indoor use to reduce vocal blast sound. Furry Windproof microphone is ideal for outdoor use to filter excess wind noise better. Different windproof covers can meet creators' needs in various scenarios.",
#         "store": "MILOUZ",
#         "product_title": "Product Title: MILOUZ Dual Wireless Microphones for iPhone/Android Phone/Camera/Laptop, Wireless Lavalier Microphone for Video Recording Podcast YouTube TikTok Facebook, Plug-Play Mini Lapel Mic",
#         "details": "{'Brand': 'MILOUZ', 'Model Name': 'AP031-Pro', 'Connectivity Technology': '\\ud83c\\udfc6 Wireless Microphones', 'Connector Type': 'Lightning，USB Type-C，3.5 mm Jack', 'Special Feature': 'CD-Level Audio Quality, Mute Function, Noise Reduction', 'Included Components': '2*Microphone transmitter, 1*3-in-1 Multi-function receiver, 2*Type-C charging cable, 1*Storage bag, 1*User manual，2*Foam Windproof，2*Microphone Clips2*Microphone transmitter, 1*3-in-1 Multi-function receiver, 2*Type-C charging cable, 1*Storage bag, 1*User manual，2*Foam Windproof，2*Microphone Clips   See more', 'Polar Pattern': 'Omnidirectional', 'Audio Sensitivity': '30 dB', 'Microphone Form Factor': 'Lavalier, Mini', 'Power Source': 'Battery Powered'}",
#         "rating_count": 548,
#         "color": "Not Specified",
#         "description": "Description: ",
#         "price": 39.99,
#         "product_id": "B0BXNNZJHQ",
#         "main_category": "Musical Instruments",
#         "sub_categories": "Categories: Musical Instruments, Microphones & Accessories, Microphones, Wireless Microphones & Systems, Wireless Lavalier Microphones"
#       },
#       "snippet": "Features: 【Noise Cancellation & CD-level Audio Quality】This professional microphone has a built-in noise reduction chip, more effectively identifying the original sound in noisy environments. Wireless Lavalier mic has omnidirectional sound reception technology and records every detail. 【Wide Compatibility】The upgraded wireless clip-on microphone has a 3 in 1 universal receiver. No need to replace "
#     },
#     {
#       "metadata": {
#         "rating_count": 1253,
#         "product_id": "B09XF54V38",
#         "store": "XIAOKOA",
#         "main_category": "Musical Instruments",
#         "sub_categories": "Categories: Musical Instruments, Microphones & Accessories, Microphones, Wireless Microphones & Systems, Wireless Headset Microphones",
#         "features": "Features: 🎤Upgraded Head Microphone: wireless microphone headset with LED Display,it can be clearly displayed the frequency,volume and battery status.▶Up to 165 feet transmission range in an open areal.▶Support 40 sets to use at the same time.🔔Not Support Mobile phone/Macbook/Laptop. 🎤Professional Wireless Microphone Headset: Built-in condenser microphone, high sensitivity pickup and prevent howling, provide you with HD sound quality.▶Adopt the latest UHF wireless technology provides a stronger signal , reducing the possibility of interference from Bluetooth or WiFi. 🎤Compatible Devices and Application:The wireless mic compatible with Voice Amplifiers,Multimedia equipment,Speakers with Mic input jack.It's ideal for class teaching,lecture,conference,also a very pop fitness headset mic. 🎤Plug and Play Head Mic:It will automatically connect when power on. If it does not connect successfully, please reconnect as follows:1⃣ Turn off the receiver and transmitter. 2⃣Turn on the transmitter, blue light is on, long press “+ ” to blue light flash. 3⃣Turn on the receiver immediately (There is no need to wait for the transmitter's blue light to stop flashing) wait for the connection. 4⃣The blue lights of both transmitter and receiver stop flashing, means connection is successful. 🎤Battery& Warranty:Built-in 400mA lithium battery,charging 2 hours,last for 5hours.▶All of our product with one year warranty,no need to worry about quality, XIAOKOA after-sales team will provide you with timely support and help.",
#         "details": "{'Item Weight': '140 Grams', 'Package Dimensions': '7.01 x 5.67 x 1.54 inches', 'Country of Origin': 'China', 'Item model number': 'U12AS', 'Batteries': '1 Lithium Ion batteries required. (included)', 'Best Sellers Rank': {'Musical Instruments': 11790, 'Wireless Headset Microphones & Systems': 45}, 'Date First Available': 'March 3, 2022', 'Color Name': 'U12AS', 'Connector Type': '3.5 mm Jack, 6.35 mm Jack', 'Battery type': 'Lithium Ion', 'Hardware Platform': 'Voice Amplifier, PA System, Speaker', 'Power Source': 'Battery Powered', 'Brand': 'XIAOKOA', 'Connectivity Technology': 'UHF', 'Special Feature': 'Wireless', 'Color': 'U12AS', 'Included Components': 'Amplifier', 'Polar Pattern': 'Omnidirectional', 'Audio Sensitivity': '58 dB', 'Microphone Form Factor': 'Headset'}",
#         "product_title": "Product Title: XIAOKOA Head Microphone,Wireless Microphone Headset,LED Digital Display Wireless Mic for Fitness,165FT Range,for Amplifier,Mic Speaker,PA System",
#         "rating": 4.0,
#         "color": "U12AS",
#         "price": 29.88,
#         "description": "Description: "
#       },
#       "snippet": "Features: 🎤Upgraded Head Microphone: wireless microphone headset with LED Display,it can be clearly displayed the frequency,volume and battery status.▶Up to 165 feet transmission range in an open areal.▶Support 40 sets to use at the same time.🔔Not Support Mobile phone/Macbook/Laptop. 🎤Professional Wireless Microphone Headset: Built-in condenser microphone, high sensitivity pickup and prevent howli"
#     },
#     {
#       "metadata": {
#         "color": "Grey",
#         "main_category": "Musical Instruments",
#         "rating": 4.6,
#         "store": "Xvive",
#         "description": "Description: ",
#         "rating_count": 1583,
#         "product_title": "Product Title: Xvive U4 Wireless in-Ear Monitor System Professional IEM System Transmitter and Beltpack Receiver for Studio, Band Rehearsal,Live Performance",
#         "features": "Features: Great 2.4GHz Band-2.4GHz wireless in-ear monitor system create your personal or team's monitor system. uncompressed wireless signal transmission, low noise and latency.Mono balanced XLR or mono unbalanced TS input.Provides smooth frequency response with any headphones. Less than 5ms Latency-Simultaneous broadcasts on 6 channels no-interference, Less than 5ms Latency,Up to 107 dB signal-to-noise ratio provides clear, detailed audio at any volume. High Resolution 24-bit/48kbps audio. Broad 20Hz-20KHz frequency response，Dynamic Rang 107 dB. Efficient Power Circuit and Listening Effect-Rechargeable Lithium Battery，5 hours of battery life(normal),comes with power cable, ensures great performance for your every show.Built-in Limiter circuitry eliminating distortion under excessive input levels. Front panel 1/4-inch monitoring has the headphone jack.it can replace traditional complex sound monitoring equipment, achieve admirable listening effect. Workmanship and Technology-Using advanced circuit design, great chips, clear the receiving blind angle to make the system's receiving signal steady. the housing is made by tough metal material.It is the best choice of monitor product.Take it out of your case or pocket, plug it in, turn on the power, Long press the CHANNEL BUTTON key to match transmitter and receiver at the same time, and play. That's how simple it is. Buy with Confidence-Xvive offer to provide quality services and products.30 days money back one year warranty, any question clicks in \"YOUR ORDER\" options click the “contact seller\"",
#         "sub_categories": "Categories: Musical Instruments, Microphones & Accessories, Microphones, Wireless Microphones & Systems, Wireless Microphone Transmitters & Receivers",
#         "product_id": "B083J8L9QT",
#         "details": "{'Item Weight': '1 Pounds', 'Package Dimensions': '6.77 x 4.57 x 2.24 inches', 'Country of Origin': 'China', 'Item model number': 'Xvive U4 In Ear Monitor System', 'Batteries': '2 Lithium Polymer batteries required. (included)', 'Best Sellers Rank': {'Musical Instruments': 387, 'Wireless Microphone Transmitters & Receivers': 4}, 'Date First Available': 'October 23, 2019', 'Color Name': 'Grey', 'Connector Type': 'XLR', 'Material Type': 'Aluminum', 'Size': 'One receiver plus one transmitter', 'Battery type': 'Lithium Ion', 'Charging Time': '5 Amps', 'Power Source': 'Battery-Powered', 'Units': '1 Count', 'Number Of Items': '1', 'Brand': 'Xvive', 'Model Name': 'Xvive U4 In Ear Monitor System', 'Color': 'Grey', 'Form Factor': 'In Ear/Over', 'Connectivity Technology': 'Wireless'}",
#         "price": 229.0
#       },
#       "snippet": "Features: Great 2.4GHz Band-2.4GHz wireless in-ear monitor system create your personal or team's monitor system. uncompressed wireless signal transmission, low noise and latency.Mono balanced XLR or mono unbalanced TS input.Provides smooth frequency response with any headphones. Less than 5ms Latency-Simultaneous broadcasts on 6 channels no-interference, Less than 5ms Latency,Up to 107 dB signal-t"
#     }
#   ]
# }

# %%
history = [
    {"role": "user", "content": "Recommend a gaming laptop"},
]

session_id = "S777"
user_id = "U007"

print("🧩 First turn — incoming:")
print_json({"session_id": session_id, "user_id": user_id, "messages": history})

result1 = run_chat(history)

print("\n🤖 First answer:")
print(result1["answer"])

print("\n📤 API response (turn 1):")
print_json({
    "status": "success",
    "session_id": session_id,
    "user_id": user_id,
    "answer": result1["answer"],
    "messages": result1["messages"],
    "retrieved": result1["retrieved"]
})
# Out:
# 🧩 First turn — incoming:
# {
#   "session_id": "S777",
#   "user_id": "U007",
#   "messages": [
#     {
#       "role": "user",
#       "content": "Recommend a gaming laptop"
#     }
#   ]
# }
#
# 🤖 First answer:
# Use ONLY the following product information to answer the question.
# If the answer is not in the context, say you don't know.
#
# CONTEXT:
# 4 or Celeron-compatible CPU or faster (multicore CPU recommended); 1 GB RAM (2 GB recommended); Windows 10, Windows 8, Windows 7, Windows Vista, or Windows XP; Windows-compatible sound card (ASIO driver support recommended); QuickTime recommended. Available USB port.
#
# ---
#
# Features: 【Portability 】The usb podcast microphone is a portable mini computer mic for travel and portability. Gaming microphone is flexibility adjustable gooseneck design, tiny enough to take up only minimal desk space. The flexible PC microphone is ideal for everyday use in both busy broadcast and live environments. 【Compatibility】USB microphone features a standard USB connection, plug n' play for both laptop and PC (no drivers required), ideal for all PC, desktop and recording applications. Great for internet voice chat, multiplayer internet gaming, video conferencing, language & other training, as well as Dragon speech recognition, dictation and transcription. (◆◆Incompatible with Xbox and Phones◆◆) 【Fully Adjustable】The USB laptop microphone is with 6.56ft cable that allows flexibility in the work area. Flexible 5.7 inch gooseneck for easy positioning, can be effortlessly adjusted to any horizontal direction and vertically to fit the comfort level of the speaker, perfect for online communications as well as voice recordings. 【Solid Construction】Sturdy metal base streaming microphone with easy-to-adjust, rugged neck can be easily positioned and relied on to keep its place.Anti-slip Rubber pad ensures base remains firmly on desk. USB condenser microphone element is surrounded by metal tubing to provide unmatched durability. Perfect for Speech Recognition with Dragon NaturallySpeaking, podcasting, Skype or other VoIP and chat programs. 【Includes】Fully 5.7" adjustable
#
# ---
#
# Description: *PLEASE NOTE:: Sound Card, 48V Phantom Power, 1/4" to XLR Cable & XLR to XLR Cable are needed to purchase additionally.*: NOTE:: 1.The Condenser Microphone only works with the device that could provide enough power: (Voltage Required:5V): for it. When connected with: desktop computer: , the Microphone could be used alone; When connected with: laptop computer: , please connect the laptop to: electrical outlet: ,or use a: 48V phantom power: to get enough power if the sound is not clear and high enough. 2.If your device could not provide enough power(when used with Amplifier or Mixer, etc.), the sound volume recorded might be low, and please use a extra 48V phantom power adapter to connect it. 3.The microphone: can not be used with mobile phone and tablet computer. NOTE: It cannot work with Mac.: 4.If you want better sound effect, a sound card should be used. 5.When recording, please put the microphone away from the amplifier to prevent recording noise due to amplifier.: (1)NW-800 Professional Condenser Microphone:: Bass-reduction switch(-10dB) reduces room noise and deals with non-linearity audio input. Fashionable design. Noble and elegant appearance.Sturdy and durable. Body weight: 11oz/316g  Color: Black Material: Metal: (1)NW-35 Scissor Arm Stand:: *Max load: Approx 35oz / 1KG* Double-braced arms equipped with super-strong spring.  Material: Steel  Extend up to Approx.31.5"/80cm.: (1)Microphone Pop Filter: (1)Metal Shock Mount: (1)Ball-type Foam Cap: (1)Table
#
# ---
#
# Product Title: JOUNIVO USB Computer Microphone JV605 PRO with Mute Button & Volume Knob Compatible with PC Laptop Desktop Mac PS4, Play & Plug Gooseneck Mic Recording for Gaming, Streaming, YouTube, Vocal
# Categories: Musical Instruments, Microphones & Accessories, Microphones, Condenser Microphones, Multipurpose
# Features: ✅360 Degree Position Adjustable Gooseneck Design --Adopting the design of metal gooseneck pipe pickup the sound from 360-degree with high sensitivity, in the best possible location for sound to your PC gaming,dragon voice dictation,and talk to Cortana ✅Mute Button & LED Indicator --One click to mute/unmute your microphone,Build-in LED indicator tells you the working status at any time. ✅Intelligent Noise Canceling Tech --Premium omnidirectional condenser microphone with noise canceling technology can pick up your clear voice and reduce background noise and echo. ✅Plug&Play -- No need to drive,Just need to plug & play for the microphone to start recording,Compatible with windows(7, 8 and 10) and Mac OS.(NOT compatible with Raspberry Pi/Linux/Android). ✅Solid Construction--Adopting premium metal pipe and heavy-duty ABS stand to make sure that you will be satisfied with our computer mic quality.
# Description:
#
# QUESTION:
# Recommend a gaming laptop
#
# ANSWER:
# Based on the product information provided, the JOUNIVO USB Computer Microphone JV605 PRO would be a suitable choice for gaming on a laptop as it is compatible with both Windows and Mac OS, and does not require any additional drivers. However, it is important to note that the microphone is not compatible with Xbox or phones, so if gaming on those platforms is a priority, a different microphone may be necessary. Additionally, the microphone's noise canceling technology and 360-degree position adjustable gooseneck design could enhance the gaming experience by picking up clear voice and reducing background noise and echo.
#
# 📤 API response (turn 1):
# {
#   "status": "success",
#   "session_id": "S777",
#   "user_id": "U007",
#   "answer": "Use ONLY the following product information to answer the question.\nIf the answer is not in the context, say you don't know.\n\nCONTEXT:\n4 or Celeron-compatible CPU or faster (multicore CPU recommended); 1 GB RAM (2 GB recommended); Windows 10, Windows 8, Windows 7, Windows Vista, or Windows XP; Windows-compatible sound card (ASIO driver support recommended); QuickTime recommended. Available USB port.\n\n---\n\nFeatures: 【Portability 】The usb podcast microphone is a portable mini computer mic for travel and portability. Gaming microphone is flexibility adjustable gooseneck design, tiny enough to take up only minimal desk space. The flexible PC microphone is ideal for everyday use in both busy broadcast and live environments. 【Compatibility】USB microphone features a standard USB connection, plug n' play for both laptop and PC (no drivers required), ideal for all PC, desktop and recording applications. Great for internet voice chat, multiplayer internet gaming, video conferencing, language & other training, as well as Dragon speech recognition, dictation and transcription. (◆◆Incompatible with Xbox and Phones◆◆) 【Fully Adjustable】The USB laptop microphone is with 6.56ft cable that allows flexibility in the work area. Flexible 5.7 inch gooseneck for easy positioning, can be effortlessly adjusted to any horizontal direction and vertically to fit the comfort level of the speaker, perfect for online communications as well as voice recordings. 【Solid Construction】Sturdy metal base streaming microphone with easy-to-adjust, rugged neck can be easily positioned and relied on to keep its place.Anti-slip Rubber pad ensures base remains firmly on desk. USB condenser microphone element is surrounded by metal tubing to provide unmatched durability. Perfect for Speech Recognition with Dragon NaturallySpeaking, podcasting, Skype or other VoIP and chat programs. 【Includes】Fully 5.7\" adjustable\n\n---\n\nDescription: *PLEASE NOTE:: Sound Card, 48V Phantom Power, 1/4\" to XLR Cable & XLR to XLR Cable are needed to purchase additionally.*: NOTE:: 1.The Condenser Microphone only works with the device that could provide enough power: (Voltage Required:5V): for it. When connected with: desktop computer: , the Microphone could be used alone; When connected with: laptop computer: , please connect the laptop to: electrical outlet: ,or use a: 48V phantom power: to get enough power if the sound is not clear and high enough. 2.If your device could not provide enough power(when used with Amplifier or Mixer, etc.), the sound volume recorded might be low, and please use a extra 48V phantom power adapter to connect it. 3.The microphone: can not be used with mobile phone and tablet computer. NOTE: It cannot work with Mac.: 4.If you want better sound effect, a sound card should be used. 5.When recording, please put the microphone away from the amplifier to prevent recording noise due to amplifier.: (1)NW-800 Professional Condenser Microphone:: Bass-reduction switch(-10dB) reduces room noise and deals with non-linearity audio input. Fashionable design. Noble and elegant appearance.Sturdy and durable. Body weight: 11oz/316g  Color: Black Material: Metal: (1)NW-35 Scissor Arm Stand:: *Max load: Approx 35oz / 1KG* Double-braced arms equipped with super-strong spring.  Material: Steel  Extend up to Approx.31.5\"/80cm.: (1)Microphone Pop Filter: (1)Metal Shock Mount: (1)Ball-type Foam Cap: (1)Table\n\n---\n\nProduct Title: JOUNIVO USB Computer Microphone JV605 PRO with Mute Button & Volume Knob Compatible with PC Laptop Desktop Mac PS4, Play & Plug Gooseneck Mic Recording for Gaming, Streaming, YouTube, Vocal\nCategories: Musical Instruments, Microphones & Accessories, Microphones, Condenser Microphones, Multipurpose\nFeatures: ✅360 Degree Position Adjustable Gooseneck Design --Adopting the design of metal gooseneck pipe pickup the sound from 360-degree with high sensitivity, in the best possible location for sound to your PC gaming,dragon voice dictati ...
#   "messages": [
#     {
#       "role": "user",
#       "content": "Recommend a gaming laptop"
#     },
#     {
#       "role": "assistant",
#       "content": "Use ONLY the following product information to answer the question.\nIf the answer is not in the context, say you don't know.\n\nCONTEXT:\n4 or Celeron-compatible CPU or faster (multicore CPU recommended); 1 GB RAM (2 GB recommended); Windows 10, Windows 8, Windows 7, Windows Vista, or Windows XP; Windows-compatible sound card (ASIO driver support recommended); QuickTime recommended. Available USB port.\n\n---\n\nFeatures: 【Portability 】The usb podcast microphone is a portable mini computer mic for travel and portability. Gaming microphone is flexibility adjustable gooseneck design, tiny enough to take up only minimal desk space. The flexible PC microphone is ideal for everyday use in both busy broadcast and live environments. 【Compatibility】USB microphone features a standard USB connection, plug n' play for both laptop and PC (no drivers required), ideal for all PC, desktop and recording applications. Great for internet voice chat, multiplayer internet gaming, video conferencing, language & other training, as well as Dragon speech recognition, dictation and transcription. (◆◆Incompatible with Xbox and Phones◆◆) 【Fully Adjustable】The USB laptop microphone is with 6.56ft cable that allows flexibility in the work area. Flexible 5.7 inch gooseneck for easy positioning, can be effortlessly adjusted to any horizontal direction and vertically to fit the comfort level of the speaker, perfect for online communications as well as voice recordings. 【Solid Construction】Sturdy metal base streaming microphone with easy-to-adjust, rugged neck can be easily positioned and relied on to keep its place.Anti-slip Rubber pad ensures base remains firmly on desk. USB condenser microphone element is surrounded by metal tubing to provide unmatched durability. Perfect for Speech Recognition with Dragon NaturallySpeaking, podcasting, Skype or other VoIP and chat programs. 【Includes】Fully 5.7\" adjustable\n\n---\n\nDescription: *PLEASE NOTE:: Sound Card, 48V Phantom Power, 1/4\" to XLR Cable & XLR to XLR Cable are needed to purchase additionally.*: NOTE:: 1.The Condenser Microphone only works with the device that could provide enough power: (Voltage Required:5V): for it. When connected with: desktop computer: , the Microphone could be used alone; When connected with: laptop computer: , please connect the laptop to: electrical outlet: ,or use a: 48V phantom power: to get enough power if the sound is not clear and high enough. 2.If your device could not provide enough power(when used with Amplifier or Mixer, etc.), the sound volume recorded might be low, and please use a extra 48V phantom power adapter to connect it. 3.The microphone: can not be used with mobile phone and tablet computer. NOTE: It cannot work with Mac.: 4.If you want better sound effect, a sound card should be used. 5.When recording, please put the microphone away from the amplifier to prevent recording noise due to amplifier.: (1)NW-800 Professional Condenser Microphone:: Bass-reduction switch(-10dB) reduces room noise and deals with non-linearity audio input. Fashionable design. Noble and elegant appearance.Sturdy and durable. Body weight: 11oz/316g  Color: Black Material: Metal: (1)NW-35 Scissor Arm Stand:: *Max load: Approx 35oz / 1KG* Double-braced arms equipped with super-strong spring.  Material: Steel  Extend up to Approx.31.5\"/80cm.: (1)Microphone Pop Filter: (1)Metal Shock Mount: (1)Ball-type Foam Cap: (1)Table\n\n---\n\nProduct Title: JOUNIVO USB Computer Microphone JV605 PRO with Mute Button & Volume Knob Compatible with PC Laptop Desktop Mac PS4, Play & Plug Gooseneck Mic Recording for Gaming, Streaming, YouTube, Vocal\nCategories: Musical Instruments, Microphones & Accessories, Microphones, Condenser Microphones, Multipurpose\nFeatures: ✅360 Degree Position Adjustable Gooseneck Design --Adopting the design of metal gooseneck pipe pickup the sound from 360-degree with high sensitivity, in the best possible location for sound to your PC gaming,dragon voice di ...
#     }
#   ],
#   "retrieved": [
#     {
#       "metadata": {
#         "sub_categories": "Categories: Musical Instruments, Studio Recording Equipment, Computer Recording, MIDI Controllers",
#         "product_id": "B08FDBCYHL",
#         "details": "{'Item Weight': '1.63 pounds', 'Product Dimensions': '7.13 x 12.52 x 1.73 inches', 'Item model number': 'MPKMINI2', 'Best Sellers Rank': {'Musical Instruments': 3190, 'Computer Recording MIDI Controllers': 22}, 'Is Discontinued By Manufacturer': 'No', 'Date First Available': 'May 28, 2014', 'Color Name': 'Red', 'Compatible Devices': 'PC', 'Connector Type': 'USB', 'Hardware Interface': 'USB', 'Material Type': 'Rubber', 'Musical Style': 'Electronic', 'Number of Keyboard Keys': '25', 'Color Screen': 'No', 'Brand': 'AKAI', 'Number of Keys': '25', 'Connectivity Technology': 'USB', 'Special Feature': 'Velo', 'Model Name': 'Old model'}",
#         "product_title": "Product Title: Akai Professional MPK Mini MKII – 25 Key USB MIDI Keyboard Controller With 8 Drum Pads, 8 Assignable Q-Link Knobs and Pro Software Suite Included",
#         "rating_count": 19689,
#         "store": "AKAI",
#         "price": 96.66,
#         "rating": 4.5,
#         "color": "Not Specified",
#         "main_category": "Musical Instruments",
#         "description": "Description: Take Control, Wherever you go! Go mobile without losing control. Akai Professional’s MPK Mini MKII is an ultra-compact keyboard controller designed for the traveling musician and the desktop producer. With a cluster of production-centric in-demand hardware controls coupled with a slim-line ultra-portable footprint, MPK Mini MKII lets you record, compose and perform with virtual instruments, effect plugins and DAWs whenever inspiration strikes. Core Control MPK Mini MKII includes all the essential tools for quickly laying down and expanding upon your musical ideas. 25 velocity-sensitive synth-action keys, a 4-way thumbstick for dynamic pitch & modulation manipulation, 8 backlit velocity-sensitive MPC-style pads and 8 assignable Q-Link knobs provide the core functionality specifically engineered for rapid production potential, all housed in an ultra-portable footprint. Express Yourself Whatever your needs, MPK Mini MKII empowers producers with essential control that’s ready to capture the idea in your head whenever inspiration strikes; dedicated Octave Up and Down buttons increase the keyboard to the full melodic range – ideal for playing basslines, chords, melodies and more; a conveniently located sustain pedal input provides expanded control for expressive, immersive performances; finally, an onboard arpeggiator with adjustable resolution, range, and modes for simple, user-friendly and rapid creation of intricate melodic lines. Plug-And-Play For maximum portability, MPK Mini MKII requires no software drivers or external power adapter for operation. Combining plug-and-play connectivity, a seamless USB-MIDI connection and power via a single USB connection to your Mac or PC, MPK Mini MKII is a portable production powerhouse. Plus, for instant-recall of critical settings, four memory banks enable you to store hardware/software presets for rapid setup of your computer and MPK Mini MKII on the fly. Hybrid 3 Hybrid 3, by AIR Music Technology, is a critically acclaimed high-definition synthesizer that can create anything from fat, retro synth sounds to edgy modern leads and everything in between. SONiVOX Wobble SONiVOX’s Wobble is an electronic music grime synthesizer that features two independent channels of spectral morphing synthesis with harmonic controls, individual filtering and discrete LFO controls. MPC Essentials With MPC Essentials, charge your production with a powerful 64-bit music production package featuring up to eight pad banks (for a total of 128 tracks), a 1 GB sound library and user-friendly import capability for your own WAV and AIFF samples. Hardware Requirements- Macintosh: 1.25 GHz G4/G5 or faster (Intel Mac recommended); 1 GB RAM (2 GB recommended); Mac OS X 10.4.11 (10.5 or later recommended). PC: 1.5 GHz Pentium 4 or Celeron-compatible CPU or faster (multicore CPU recommended); 1 GB RAM (2 GB recommended); Windows 10, Windows 8, Windows 7, Windows Vista, or Windows XP; Windows-compatible sound card (ASIO driver support recommended); QuickTime recommended. Available USB port.",
#         "features": "Features: Compact keyboard controller easily fits backpack and studio production desk (12.4\" long, 1.6 lbs) Powered by USB connection to computer, with free virtual-instrument download packages Crammed full of all the features you need to play and edit musical ideas 25-synth-action mini-keys, 8 velocity-sensitive rubber drum pads with two banks, and eight assignable control knobs Dedicated buttons for Note Repeat, Full Level, and Octave Up and Down 1400 Sounds and Everything You Need For Pro Production: Production software package for Mac and PC included: Akai Pro MPC Essentials, SONiVOX Wobble, and Hybrid 3 by AIR Music Tech (downloads)"
#       },
#       "snippet": "4 or Celeron-compatible CPU or faster (multicore CPU recommended); 1 GB RAM (2 GB recommended); Windows 10, Windows 8, Windows 7, Windows Vista, or Windows XP; Windows-compatible sound card (ASIO driver support recommended); QuickTime recommended. Available USB port."
#     },
#     {
#       "metadata": {
#         "product_title": "Product Title: FIFINE Mini Gooseneck USB Microphone for Dictation and Recording,Desktop Microphone for Computer Laptop PC.Plug and Play Great for Skype,YouTube,Gaming, Streaming,Voiceover,Discord and Tutorials-K050",
#         "store": "FIFINE",
#         "rating_count": 879,
#         "features": "Features: 【Portability 】The usb podcast microphone is a portable mini computer mic for travel and portability. Gaming microphone is flexibility adjustable gooseneck design, tiny enough to take up only minimal desk space. The flexible PC microphone is ideal for everyday use in both busy broadcast and live environments. 【Compatibility】USB microphone features a standard USB connection, plug n' play for both laptop and PC (no drivers required), ideal for all PC, desktop and recording applications. Great for internet voice chat, multiplayer internet gaming, video conferencing, language & other training, as well as Dragon speech recognition, dictation and transcription. (◆◆Incompatible with Xbox and Phones◆◆) 【Fully Adjustable】The USB laptop microphone is with 6.56ft cable that allows flexibility in the work area. Flexible 5.7 inch gooseneck for easy positioning, can be effortlessly adjusted to any horizontal direction and vertically to fit the comfort level of the speaker, perfect for online communications as well as voice recordings. 【Solid Construction】Sturdy metal base streaming microphone with easy-to-adjust, rugged neck can be easily positioned and relied on to keep its place.Anti-slip Rubber pad ensures base remains firmly on desk. USB condenser microphone element is surrounded by metal tubing to provide unmatched durability. Perfect for Speech Recognition with Dragon NaturallySpeaking, podcasting, Skype or other VoIP and chat programs. 【Includes】Fully 5.7\" adjustable gooseneck microphone with usb cable (6.56ft long shielded cord can easily withstand environmental damage), a windscreen to reduces background noise and improves sound quality. Friendly Technical Support.",
#         "color": "Black",
#         "product_id": "B07VV9ZBNM",
#         "rating": 4.4,
#         "details": "{'Item Weight': '5.3 ounces', 'Product Dimensions': '2.6 x 2.6 x 6.61 inches', 'Country of Origin': 'China', 'Item model number': 'K050', 'Best Sellers Rank': {'Musical Instruments': 5117, 'Multipurpose Condenser Microphones': 103}, 'Date First Available': 'June 23, 2019', 'Color Name': 'Black', 'Compatible Devices': 'Laptop, Personal Computer', 'Connector Type': 'USB', 'Material Type': 'Metal', 'Hardware Platform': 'Laptop, Gaming Console, PC', 'Power Source': 'Usb Microphone,Usb Condenser', 'Recommended Uses For Product': 'Meeting/On Line Course/Kids Use', 'Brand': 'FIFINE', 'Connectivity Technology': 'USB', 'Special Feature': 'Portability/Compatibility/Solid Construction', 'Color': 'Black', 'Included Components': \"Gooseneck microphone with usb cable, windscreen, user's Manual\", 'Polar Pattern': 'Unidirectional', 'Item Dimensions LxWxH': '2.6 x 2.6 x 6.61 inches'}",
#         "main_category": "Musical Instruments",
#         "price": 19.99,
#         "sub_categories": "Categories: Musical Instruments, Microphones & Accessories, Microphones, Condenser Microphones, Multipurpose",
#         "description": "Description: "
#       },
#       "snippet": "Features: 【Portability 】The usb podcast microphone is a portable mini computer mic for travel and portability. Gaming microphone is flexibility adjustable gooseneck design, tiny enough to take up only minimal desk space. The flexible PC microphone is ideal for everyday use in both busy broadcast and live environments. 【Compatibility】USB microphone features a standard USB connection, plug n' play f"
#     },
#     {
#       "metadata": {
#         "features": "Features: This Kit Includes:(1)Condenser Microphone + (1)Adjustable Suspension Scissor Arm Stand + (1)Table Mounting Clamp + (1)Metal Shock Mount + (1)Pop Filter + (1)Ball-type Anti-wind Foam Cap + (1)3.5mm Male to XLR Female Cable. *PLEASE NOTE: Sound Card, 48V Phantom Power, 1/4\" to XLR Cable & XLR to XLR Cable are needed to purchase additionally.* The professional condenser microphone adopts the completely new audio circuit. Capture rich, full-bodied sound from sources that are directly in front of the mic. The cardioid pick-up pattern minimizes background noise and isolates the main sound source. The adjustable scissor arm stand is made out of all steel construction, sturdy and durable. Folding type, convenient to carry. Can be mounted on the announcers' table. The double-braced arms add strength. *Max load: Approx 35oz / 1KG* The microphone wind screen pop filter mask shield can ensure that your tracks are audible and easy to understand.And also it will make sure your message loud and clear, and banish the dreaded hissing and lisping sounds. The metal shock mount features an angle adjustment with locking knob and can effectively reduce handling noise. The ball-type anti-wind foam cap can protect microphone against wind interference and singers'spit.",
#         "description": "Description: *PLEASE NOTE:: Sound Card, 48V Phantom Power, 1/4\" to XLR Cable & XLR to XLR Cable are needed to purchase additionally.*: NOTE:: 1.The Condenser Microphone only works with the device that could provide enough power: (Voltage Required:5V): for it. When connected with: desktop computer: , the Microphone could be used alone; When connected with: laptop computer: , please connect the laptop to: electrical outlet: ,or use a: 48V phantom power: to get enough power if the sound is not clear and high enough. 2.If your device could not provide enough power(when used with Amplifier or Mixer, etc.), the sound volume recorded might be low, and please use a extra 48V phantom power adapter to connect it. 3.The microphone: can not be used with mobile phone and tablet computer. NOTE: It cannot work with Mac.: 4.If you want better sound effect, a sound card should be used. 5.When recording, please put the microphone away from the amplifier to prevent recording noise due to amplifier.: (1)NW-800 Professional Condenser Microphone:: Bass-reduction switch(-10dB) reduces room noise and deals with non-linearity audio input. Fashionable design. Noble and elegant appearance.Sturdy and durable. Body weight: 11oz/316g  Color: Black Material: Metal: (1)NW-35 Scissor Arm Stand:: *Max load: Approx 35oz / 1KG* Double-braced arms equipped with super-strong spring.  Material: Steel  Extend up to Approx.31.5\"/80cm.: (1)Microphone Pop Filter: (1)Metal Shock Mount: (1)Ball-type Foam Cap: (1)Table Mounting Clamp: (1)3.5mm Male to XLR Female Cable:: Length: Approx. 8.2ft/2.5m",
#         "store": "Neewer",
#         "product_id": "B01I6LIZ8S",
#         "rating": 4.2,
#         "rating_count": 5247,
#         "price": 30.5,
#         "main_category": "Musical Instruments",
#         "details": "{'Item Weight': '11 Ounces', 'Product Dimensions': '15.94 x 7.48 x 3.86 inches', 'Item model number': '40091550', 'Batteries': '1 Lithium Ion batteries required.', 'Best Sellers Rank': {'Musical Instruments': 15476, 'Vocal Condenser Microphones': 29}, 'Is Discontinued By Manufacturer': 'No', 'Date First Available': 'July 9, 2016', 'Compatible Devices': 'Laptop, Personal Computer, Tablet, Amplifier, Smartphone', 'Connector Type': '3.5 mm Jack, XLR Connector', 'Material Type': 'Metal', 'Hardware Platform': 'Smartphone', 'Power Source': 'Corded Electric', 'Recommended Uses For Product': 'Singing', 'Brand': 'Neewer', 'Connectivity Technology': 'XLR', 'Special Feature': 'Stand', 'Included Components': 'Microphone, Power_adapter, Amplifier', 'Polar Pattern': 'Unidirectional', 'Audio Sensitivity': '10 dB'}",
#         "color": "Not Specified",
#         "sub_categories": "Categories: Musical Instruments, Microphones & Accessories, Microphones, Condenser Microphones, Vocal",
#         "product_title": "Product Title: Neewer Professional Studio Broadcasting Recording Condenser Microphone & NW- 35 Adjustable Recording Microphone Suspension Scissor Arm Stand with Shock Mount and Mounting Clamp Kit"
#       },
#       "snippet": "Description: *PLEASE NOTE:: Sound Card, 48V Phantom Power, 1/4\" to XLR Cable & XLR to XLR Cable are needed to purchase additionally.*: NOTE:: 1.The Condenser Microphone only works with the device that could provide enough power: (Voltage Required:5V): for it. When connected with: desktop computer: , the Microphone could be used alone; When connected with: laptop computer: , please connect the lapt"
#     },
#     {
#       "metadata": {
#         "details": "{'Brand': 'JOUNIVO', 'Series': 'JV-605PRO', 'Item model number': 'JV-605PRO', 'Hardware Platform': 'Laptop, Gaming Console, PC', 'Item Weight': '11 ounces', 'Product Dimensions': '3.96 x 3.96 x 12 inches', 'Item Dimensions  LxWxH': '3.96 x 3.96 x 12 inches', 'Color': 'JV-605PRO', 'Power Source': 'Corded Electric', 'Manufacturer': 'JOUNIVO', 'Is Discontinued By Manufacturer': 'No', 'Date First Available': 'October 3, 2019', 'Best Sellers Rank': {'Musical Instruments': 11551, 'Multipurpose Condenser Microphones': 204}, 'Recommended Uses For Product': 'Streaming', 'Model Name': 'JV-605PRO', 'Connectivity Technology': 'USB', 'Connector Type': 'USB Type-A', 'Special Feature': 'Mute Function', 'Compatible Devices': 'Laptop', 'Included Components': 'Microphone', 'Polar Pattern': 'Unidirectional'}",
#         "features": "Features: ✅360 Degree Position Adjustable Gooseneck Design --Adopting the design of metal gooseneck pipe pickup the sound from 360-degree with high sensitivity, in the best possible location for sound to your PC gaming,dragon voice dictation,and talk to Cortana ✅Mute Button & LED Indicator --One click to mute/unmute your microphone,Build-in LED indicator tells you the working status at any time. ✅Intelligent Noise Canceling Tech --Premium omnidirectional condenser microphone with noise canceling technology can pick up your clear voice and reduce background noise and echo. ✅Plug&Play -- No need to drive,Just need to plug & play for the microphone to start recording,Compatible with windows(7, 8 and 10) and Mac OS.(NOT compatible with Raspberry Pi/Linux/Android). ✅Solid Construction--Adopting premium metal pipe and heavy-duty ABS stand to make sure that you will be satisfied with our computer mic quality.",
#         "main_category": "Computers",
#         "price": 15.99,
#         "store": "JOUNIVO",
#         "rating_count": 1209,
#         "product_id": "B07YNKJNTR",
#         "color": "JV-605PRO",
#         "rating": 4.2,
#         "description": "Description: ",
#         "sub_categories": "Categories: Musical Instruments, Microphones & Accessories, Microphones, Condenser Microphones, Multipurpose",
#         "product_title": "Product Title: JOUNIVO USB Computer Microphone JV605 PRO with Mute Button & Volume Knob Compatible with PC Laptop Desktop Mac PS4, Play & Plug Gooseneck Mic Recording for Gaming, Streaming, YouTube, Vocal"
#       },
#       "snippet": "Product Title: JOUNIVO USB Computer Microphone JV605 PRO with Mute Button & Volume Knob Compatible with PC Laptop Desktop Mac PS4, Play & Plug Gooseneck Mic Recording for Gaming, Streaming, YouTube, Vocal\nCategories: Musical Instruments, Microphones & Accessories, Microphones, Condenser Microphones, Multipurpose\nFeatures: ✅360 Degree Position Adjustable Gooseneck Design --Adopting the design of me"
#     }
#   ]
# }

# %%
history2 = result1["messages"] + [
    {"role": "user", "content": "What about something cheap but still good?"}
]

print("🧩 Second turn — incoming:")
print_json({"session_id": session_id, "user_id": user_id, "messages": history2})

result2 = run_chat(history2)

print("\n🤖 Second answer:")
print(result2["answer"])

print("\n📤 API response (turn 2):")
print_json({
    "status": "success",
    "session_id": session_id,
    "user_id": user_id,
    "answer": result2["answer"],
    "messages": result2["messages"],
    "retrieved": result2["retrieved"]
})
# Out:
# 🧩 Second turn — incoming:
# {
#   "session_id": "S777",
#   "user_id": "U007",
#   "messages": [
#     {
#       "role": "user",
#       "content": "Recommend a gaming laptop"
#     },
#     {
#       "role": "assistant",
#       "content": "Use ONLY the following product information to answer the question.\nIf the answer is not in the context, say you don't know.\n\nCONTEXT:\n4 or Celeron-compatible CPU or faster (multicore CPU recommended); 1 GB RAM (2 GB recommended); Windows 10, Windows 8, Windows 7, Windows Vista, or Windows XP; Windows-compatible sound card (ASIO driver support recommended); QuickTime recommended. Available USB port.\n\n---\n\nFeatures: 【Portability 】The usb podcast microphone is a portable mini computer mic for travel and portability. Gaming microphone is flexibility adjustable gooseneck design, tiny enough to take up only minimal desk space. The flexible PC microphone is ideal for everyday use in both busy broadcast and live environments. 【Compatibility】USB microphone features a standard USB connection, plug n' play for both laptop and PC (no drivers required), ideal for all PC, desktop and recording applications. Great for internet voice chat, multiplayer internet gaming, video conferencing, language & other training, as well as Dragon speech recognition, dictation and transcription. (◆◆Incompatible with Xbox and Phones◆◆) 【Fully Adjustable】The USB laptop microphone is with 6.56ft cable that allows flexibility in the work area. Flexible 5.7 inch gooseneck for easy positioning, can be effortlessly adjusted to any horizontal direction and vertically to fit the comfort level of the speaker, perfect for online communications as well as voice recordings. 【Solid Construction】Sturdy metal base streaming microphone with easy-to-adjust, rugged neck can be easily positioned and relied on to keep its place.Anti-slip Rubber pad ensures base remains firmly on desk. USB condenser microphone element is surrounded by metal tubing to provide unmatched durability. Perfect for Speech Recognition with Dragon NaturallySpeaking, podcasting, Skype or other VoIP and chat programs. 【Includes】Fully 5.7\" adjustable\n\n---\n\nDescription: *PLEASE NOTE:: Sound Card, 48V Phantom Power, 1/4\" to XLR Cable & XLR to XLR Cable are needed to purchase additionally.*: NOTE:: 1.The Condenser Microphone only works with the device that could provide enough power: (Voltage Required:5V): for it. When connected with: desktop computer: , the Microphone could be used alone; When connected with: laptop computer: , please connect the laptop to: electrical outlet: ,or use a: 48V phantom power: to get enough power if the sound is not clear and high enough. 2.If your device could not provide enough power(when used with Amplifier or Mixer, etc.), the sound volume recorded might be low, and please use a extra 48V phantom power adapter to connect it. 3.The microphone: can not be used with mobile phone and tablet computer. NOTE: It cannot work with Mac.: 4.If you want better sound effect, a sound card should be used. 5.When recording, please put the microphone away from the amplifier to prevent recording noise due to amplifier.: (1)NW-800 Professional Condenser Microphone:: Bass-reduction switch(-10dB) reduces room noise and deals with non-linearity audio input. Fashionable design. Noble and elegant appearance.Sturdy and durable. Body weight: 11oz/316g  Color: Black Material: Metal: (1)NW-35 Scissor Arm Stand:: *Max load: Approx 35oz / 1KG* Double-braced arms equipped with super-strong spring.  Material: Steel  Extend up to Approx.31.5\"/80cm.: (1)Microphone Pop Filter: (1)Metal Shock Mount: (1)Ball-type Foam Cap: (1)Table\n\n---\n\nProduct Title: JOUNIVO USB Computer Microphone JV605 PRO with Mute Button & Volume Knob Compatible with PC Laptop Desktop Mac PS4, Play & Plug Gooseneck Mic Recording for Gaming, Streaming, YouTube, Vocal\nCategories: Musical Instruments, Microphones & Accessories, Microphones, Condenser Microphones, Multipurpose\nFeatures: ✅360 Degree Position Adjustable Gooseneck Design --Adopting the design of metal gooseneck pipe pickup the sound from 360-degree with high sensitivity, in the best possible location for sound to your PC gaming,dragon voice di ...
#     },
#     {
#       "role": "user",
#       "content": "What about something cheap but still good?"
#     }
#   ]
# }
#
# 🤖 Second answer:
# Use ONLY the following product information to answer the question.
# If the answer is not in the context, say you don't know.
#
# CONTEXT:
# a special and strong zipper, which can bring you a better using experience. For sale is CASE ONLY! (Akai mpk mini midi keyboard and midi piano keyboard for computer accessories are not included)
#
# ---
#
# Features: &#x1F3BB [Satisfying Practice & Thrilling Perform] Vangoa silent electric violin perfectly fits beginners to bring quiet moments for families, during your learning time. With headphones, you can be immersed in happy melodies, without bothering others, and progress rapidly. It's amp connectable to play louder, showing your musical talent on stage/party &#x2728 [Quality Durable Material] Premium Solid maple wood body in black metallic varnish produces a crisper, more resonant, and brighter sound. Selected ebony fretboard ensures smooth playing while solid maple head, pegs, and chin rest are durable for a long period of practice &#xF3B6 [Pleasing Sound] Carbon fiber tailpiece with 4 detachable fine tuners can tune precisely. Robust durable steel strings add richness and power to the sound. Brazilwood bow with unbleached natural horsehair pulls out the best-balanced sound &#x1F3BB [More Size Options for Everyone] Picking the most appropriate size is essential for a comfortable start. Offer 3 sizes for students, kids, teens, adults, beginners, and advanced players. And it is lightweight, less likely to make players' arms tired and sore to ensure long-time practice &#x1F497 [Useful Beginner Kit] Includes a hard case, extra strings, rosin, and headphone. You can get all the things you need in one purchase, it is cost-effective and time-saving. We provide a 1-year warranty, aiming to provide customers with high-quality products and sincere service. If you have any
#
# ---
#
# Direct: If you're a working musician who demands uncompromising functionality and durability, the ULTRA-DI DI20 will astound you - and so will its very affordable price tag. See what the DI20 can do for your sound today at your nearest BEHRINGER dealer.
#
# ---
#
# Features: MAJOR UPGRADE FROM "STOCK" STARTER CYMBALS: these are not those distractingly cheap, flimsy prop cymbals that come with most drum sets; Meinl HCS cymbals have impressive sound and sturdy feel geared toward beginner/intermediate players WHY IT MATTERS: playing HCS cymbals will sound more like what you hear in actual songs, making the drums even more fun to play; plus, they aren't going to fall apart, dent, or bend after a few uses like stock cymbals WHAT'S IN THE BOX: includes one 14" crash cymbal; this crash cuts through music with a clear attack and balanced sustain that doesn't linger too long; it delivers exceptional punch to accent the beat, and it blends with all other HCS crash sizes DRIVING THE SOUND: made in Germany with MS63 brass alloy for a clean, bright, and crisp tone; substantial thickness with well-formed surface grooves and hammer marks give you a defined sound without clangy or ear-piercing overtones CATCH UP QUICK: HCS exceeds expectations because Meinl brings experience crafting cymbals since 1951; we make HCS and other lines in our German factory, and our top-of-the-line professional Byzance cymbals are hand hammered in Turkey from cast B20 bronze ZOOM IN: the surface shimmers and shines under light, which is a bonus if you like your kit to look beautiful; HCS cymbals also feature the same logo treatment as our professional lines, including a small laser engraved logo and serial number OF NOTE: you can find any sound in the seemingly
#
# QUESTION:
# What about something cheap but still good?
#
# ANSWER:
# Based on the product information provided, the Meinl HCS cymbals would be a good option for someone looking for a cheap but still good alternative. These cymbals are a major upgrade from "stock" starter cymbals and have impressive sound and sturdy feel geared toward beginner/intermediate players. They also won't fall apart, dent, or bend after a few uses like stock cymbals. While the product information doesn't specifically mention the price, it does state that these cymbals are more affordable than other options, making them a cost-effective choice. Overall, the Meinl HCS cymbals offer a clear attack and balanced sustain that doesn't linger too long, delivering exceptional punch to accent the beat and blending well with other HCS crash sizes.
#
# 📤 API response (turn 2):
# {
#   "status": "success",
#   "session_id": "S777",
#   "user_id": "U007",
#   "answer": "Use ONLY the following product information to answer the question.\nIf the answer is not in the context, say you don't know.\n\nCONTEXT:\na special and strong zipper, which can bring you a better using experience. For sale is CASE ONLY! (Akai mpk mini midi keyboard and midi piano keyboard for computer accessories are not included)\n\n---\n\nFeatures: &#x1F3BB [Satisfying Practice & Thrilling Perform] Vangoa silent electric violin perfectly fits beginners to bring quiet moments for families, during your learning time. With headphones, you can be immersed in happy melodies, without bothering others, and progress rapidly. It's amp connectable to play louder, showing your musical talent on stage/party &#x2728 [Quality Durable Material] Premium Solid maple wood body in black metallic varnish produces a crisper, more resonant, and brighter sound. Selected ebony fretboard ensures smooth playing while solid maple head, pegs, and chin rest are durable for a long period of practice &#xF3B6 [Pleasing Sound] Carbon fiber tailpiece with 4 detachable fine tuners can tune precisely. Robust durable steel strings add richness and power to the sound. Brazilwood bow with unbleached natural horsehair pulls out the best-balanced sound &#x1F3BB [More Size Options for Everyone] Picking the most appropriate size is essential for a comfortable start. Offer 3 sizes for students, kids, teens, adults, beginners, and advanced players. And it is lightweight, less likely to make players' arms tired and sore to ensure long-time practice &#x1F497 [Useful Beginner Kit] Includes a hard case, extra strings, rosin, and headphone. You can get all the things you need in one purchase, it is cost-effective and time-saving. We provide a 1-year warranty, aiming to provide customers with high-quality products and sincere service. If you have any\n\n---\n\nDirect: If you're a working musician who demands uncompromising functionality and durability, the ULTRA-DI DI20 will astound you - and so will its very affordable price tag. See what the DI20 can do for your sound today at your nearest BEHRINGER dealer.\n\n---\n\nFeatures: MAJOR UPGRADE FROM \"STOCK\" STARTER CYMBALS: these are not those distractingly cheap, flimsy prop cymbals that come with most drum sets; Meinl HCS cymbals have impressive sound and sturdy feel geared toward beginner/intermediate players WHY IT MATTERS: playing HCS cymbals will sound more like what you hear in actual songs, making the drums even more fun to play; plus, they aren't going to fall apart, dent, or bend after a few uses like stock cymbals WHAT'S IN THE BOX: includes one 14\" crash cymbal; this crash cuts through music with a clear attack and balanced sustain that doesn't linger too long; it delivers exceptional punch to accent the beat, and it blends with all other HCS crash sizes DRIVING THE SOUND: made in Germany with MS63 brass alloy for a clean, bright, and crisp tone; substantial thickness with well-formed surface grooves and hammer marks give you a defined sound without clangy or ear-piercing overtones CATCH UP QUICK: HCS exceeds expectations because Meinl brings experience crafting cymbals since 1951; we make HCS and other lines in our German factory, and our top-of-the-line professional Byzance cymbals are hand hammered in Turkey from cast B20 bronze ZOOM IN: the surface shimmers and shines under light, which is a bonus if you like your kit to look beautiful; HCS cymbals also feature the same logo treatment as our professional lines, including a small laser engraved logo and serial number OF NOTE: you can find any sound in the seemingly\n\nQUESTION:\nWhat about something cheap but still good?\n\nANSWER:\nBased on the product information provided, the Meinl HCS cymbals would be a good option for someone looking for a cheap but still good alternative. These cymbals are a major upgrade from \"stock\" starter cymbals and have impressive sound and sturdy feel geared toward beginner/intermediate players. They also won't fal ...
#   "messages": [
#     {
#       "role": "user",
#       "content": "Recommend a gaming laptop"
#     },
#     {
#       "role": "assistant",
#       "content": "Use ONLY the following product information to answer the question.\nIf the answer is not in the context, say you don't know.\n\nCONTEXT:\n4 or Celeron-compatible CPU or faster (multicore CPU recommended); 1 GB RAM (2 GB recommended); Windows 10, Windows 8, Windows 7, Windows Vista, or Windows XP; Windows-compatible sound card (ASIO driver support recommended); QuickTime recommended. Available USB port.\n\n---\n\nFeatures: 【Portability 】The usb podcast microphone is a portable mini computer mic for travel and portability. Gaming microphone is flexibility adjustable gooseneck design, tiny enough to take up only minimal desk space. The flexible PC microphone is ideal for everyday use in both busy broadcast and live environments. 【Compatibility】USB microphone features a standard USB connection, plug n' play for both laptop and PC (no drivers required), ideal for all PC, desktop and recording applications. Great for internet voice chat, multiplayer internet gaming, video conferencing, language & other training, as well as Dragon speech recognition, dictation and transcription. (◆◆Incompatible with Xbox and Phones◆◆) 【Fully Adjustable】The USB laptop microphone is with 6.56ft cable that allows flexibility in the work area. Flexible 5.7 inch gooseneck for easy positioning, can be effortlessly adjusted to any horizontal direction and vertically to fit the comfort level of the speaker, perfect for online communications as well as voice recordings. 【Solid Construction】Sturdy metal base streaming microphone with easy-to-adjust, rugged neck can be easily positioned and relied on to keep its place.Anti-slip Rubber pad ensures base remains firmly on desk. USB condenser microphone element is surrounded by metal tubing to provide unmatched durability. Perfect for Speech Recognition with Dragon NaturallySpeaking, podcasting, Skype or other VoIP and chat programs. 【Includes】Fully 5.7\" adjustable\n\n---\n\nDescription: *PLEASE NOTE:: Sound Card, 48V Phantom Power, 1/4\" to XLR Cable & XLR to XLR Cable are needed to purchase additionally.*: NOTE:: 1.The Condenser Microphone only works with the device that could provide enough power: (Voltage Required:5V): for it. When connected with: desktop computer: , the Microphone could be used alone; When connected with: laptop computer: , please connect the laptop to: electrical outlet: ,or use a: 48V phantom power: to get enough power if the sound is not clear and high enough. 2.If your device could not provide enough power(when used with Amplifier or Mixer, etc.), the sound volume recorded might be low, and please use a extra 48V phantom power adapter to connect it. 3.The microphone: can not be used with mobile phone and tablet computer. NOTE: It cannot work with Mac.: 4.If you want better sound effect, a sound card should be used. 5.When recording, please put the microphone away from the amplifier to prevent recording noise due to amplifier.: (1)NW-800 Professional Condenser Microphone:: Bass-reduction switch(-10dB) reduces room noise and deals with non-linearity audio input. Fashionable design. Noble and elegant appearance.Sturdy and durable. Body weight: 11oz/316g  Color: Black Material: Metal: (1)NW-35 Scissor Arm Stand:: *Max load: Approx 35oz / 1KG* Double-braced arms equipped with super-strong spring.  Material: Steel  Extend up to Approx.31.5\"/80cm.: (1)Microphone Pop Filter: (1)Metal Shock Mount: (1)Ball-type Foam Cap: (1)Table\n\n---\n\nProduct Title: JOUNIVO USB Computer Microphone JV605 PRO with Mute Button & Volume Knob Compatible with PC Laptop Desktop Mac PS4, Play & Plug Gooseneck Mic Recording for Gaming, Streaming, YouTube, Vocal\nCategories: Musical Instruments, Microphones & Accessories, Microphones, Condenser Microphones, Multipurpose\nFeatures: ✅360 Degree Position Adjustable Gooseneck Design --Adopting the design of metal gooseneck pipe pickup the sound from 360-degree with high sensitivity, in the best possible location for sound to your PC gaming,dragon voice di ...
#     },
#     {
#       "role": "user",
#       "content": "What about something cheap but still good?"
#     },
#     {
#       "role": "assistant",
#       "content": "Use ONLY the following product information to answer the question.\nIf the answer is not in the context, say you don't know.\n\nCONTEXT:\na special and strong zipper, which can bring you a better using experience. For sale is CASE ONLY! (Akai mpk mini midi keyboard and midi piano keyboard for computer accessories are not included)\n\n---\n\nFeatures: &#x1F3BB [Satisfying Practice & Thrilling Perform] Vangoa silent electric violin perfectly fits beginners to bring quiet moments for families, during your learning time. With headphones, you can be immersed in happy melodies, without bothering others, and progress rapidly. It's amp connectable to play louder, showing your musical talent on stage/party &#x2728 [Quality Durable Material] Premium Solid maple wood body in black metallic varnish produces a crisper, more resonant, and brighter sound. Selected ebony fretboard ensures smooth playing while solid maple head, pegs, and chin rest are durable for a long period of practice &#xF3B6 [Pleasing Sound] Carbon fiber tailpiece with 4 detachable fine tuners can tune precisely. Robust durable steel strings add richness and power to the sound. Brazilwood bow with unbleached natural horsehair pulls out the best-balanced sound &#x1F3BB [More Size Options for Everyone] Picking the most appropriate size is essential for a comfortable start. Offer 3 sizes for students, kids, teens, adults, beginners, and advanced players. And it is lightweight, less likely to make players' arms tired and sore to ensure long-time practice &#x1F497 [Useful Beginner Kit] Includes a hard case, extra strings, rosin, and headphone. You can get all the things you need in one purchase, it is cost-effective and time-saving. We provide a 1-year warranty, aiming to provide customers with high-quality products and sincere service. If you have any\n\n---\n\nDirect: If you're a working musician who demands uncompromising functionality and durability, the ULTRA-DI DI20 will astound you - and so will its very affordable price tag. See what the DI20 can do for your sound today at your nearest BEHRINGER dealer.\n\n---\n\nFeatures: MAJOR UPGRADE FROM \"STOCK\" STARTER CYMBALS: these are not those distractingly cheap, flimsy prop cymbals that come with most drum sets; Meinl HCS cymbals have impressive sound and sturdy feel geared toward beginner/intermediate players WHY IT MATTERS: playing HCS cymbals will sound more like what you hear in actual songs, making the drums even more fun to play; plus, they aren't going to fall apart, dent, or bend after a few uses like stock cymbals WHAT'S IN THE BOX: includes one 14\" crash cymbal; this crash cuts through music with a clear attack and balanced sustain that doesn't linger too long; it delivers exceptional punch to accent the beat, and it blends with all other HCS crash sizes DRIVING THE SOUND: made in Germany with MS63 brass alloy for a clean, bright, and crisp tone; substantial thickness with well-formed surface grooves and hammer marks give you a defined sound without clangy or ear-piercing overtones CATCH UP QUICK: HCS exceeds expectations because Meinl brings experience crafting cymbals since 1951; we make HCS and other lines in our German factory, and our top-of-the-line professional Byzance cymbals are hand hammered in Turkey from cast B20 bronze ZOOM IN: the surface shimmers and shines under light, which is a bonus if you like your kit to look beautiful; HCS cymbals also feature the same logo treatment as our professional lines, including a small laser engraved logo and serial number OF NOTE: you can find any sound in the seemingly\n\nQUESTION:\nWhat about something cheap but still good?\n\nANSWER:\nBased on the product information provided, the Meinl HCS cymbals would be a good option for someone looking for a cheap but still good alternative. These cymbals are a major upgrade from \"stock\" starter cymbals and have impressive sound and sturdy feel geared toward beginner/intermediate players. They also won' ...
#     }
#   ],
#   "retrieved": [
#     {
#       "metadata": {
#         "product_title": "Product Title: co2CREA Hard Case replacement for AKAI Professional MPK Mini MK3 / MPK Mini Play MK3 25 Key USB MIDI Keyboard Controller",
#         "product_id": "B09ZNNYMQ9",
#         "color": "All Black Case",
#         "features": "Features: co2CREA hard travel case replacement for Akai professional mpk mini mk3 midi keyboard sound board controller or Akai mpk mini play mk3 25 key usb midi keyboard controller. Hard EVA shell case is shockproof dustproof and water resistance, protect your Akai mpk mini mk3 mini keyboard piano Akai midi keyboard beat machine from drops, scratches, bumps, splash, and dust. This Akai mpk mini mk3 mini piano synthesizer keyboard protection case perfect for your Akai mpk mini mk3 midi keyboard sound board mini piano keyboard or Akai mpk mini play mk3 25 key usb midi keyboard computer recording midi controllers. And this Akai mpk mini mk2 mini midi keyboard case has more space to accommodate the Akai professional mpk mini mk3 controlador midi piano and more accessories. co2CREA hard Akai mini mk3 midi controller keyboard protective case is a build-in super quality lining reflects superior taste and ensures a long-lasting performance, the soft anti static lining can protect your Akai professional mpk mini mk3 midi drum pad music instruments beat maker machine musical keyboard from bumps dents and scratches. This Akai mpk mini mk3 mini DJ controller case has a comfortable hand strap, so that the Akai professional mpk mini mk3 drum machine beat maker music pad electronic music equipment can travel with you easily. and this Akai mini mk3 sound board mini keyboard piano case has a special and strong zipper, which can bring you a better using experience. For sale is CASE ONLY! (Akai mpk mini midi keyboard and midi piano keyboard for computer accessories are not included)",
#         "rating": 4.7,
#         "price": 29.99,
#         "store": "co2CREA",
#         "description": "Description: ",
#         "rating_count": 1209,
#         "main_category": "Musical Instruments",
#         "details": "{'Item Weight': '15.5 ounces', 'Package Dimensions': '13.74 x 10.03 x 2.48 inches', 'Item model number': 'CA-0814-1162', 'Best Sellers Rank': {'Musical Instruments': 5710, 'Computer Recording MIDI Controllers': 39}, 'Date First Available': 'August 14, 2020', 'Color Name': 'All Black Case', 'Connector Type': 'USB', 'Hardware Interface': 'USB', 'Material Type': 'Eva', 'Musical Style': 'Electronic', 'Brand': 'co2CREA', 'Connectivity Technology': 'USB', 'Special Feature': 'Keyboard Controller', 'Color': 'All Black Case', 'Style': 'MPK Mini MK3'}",
#         "sub_categories": "Categories: Musical Instruments, Studio Recording Equipment, Computer Recording, MIDI Controllers"
#       },
#       "snippet": "a special and strong zipper, which can bring you a better using experience. For sale is CASE ONLY! (Akai mpk mini midi keyboard and midi piano keyboard for computer accessories are not included)"
#     },
#     {
#       "metadata": {
#         "rating": 4.0,
#         "product_id": "B0B1T7BM9X",
#         "description": "Description: ",
#         "price": 129.95,
#         "rating_count": 626,
#         "main_category": "Musical Instruments",
#         "features": "Features: &#x1F3BB [Satisfying Practice & Thrilling Perform] Vangoa silent electric violin perfectly fits beginners to bring quiet moments for families, during your learning time. With headphones, you can be immersed in happy melodies, without bothering others, and progress rapidly. It's amp connectable to play louder, showing your musical talent on stage/party &#x2728 [Quality Durable Material] Premium Solid maple wood body in black metallic varnish produces a crisper, more resonant, and brighter sound. Selected ebony fretboard ensures smooth playing while solid maple head, pegs, and chin rest are durable for a long period of practice &#xF3B6 [Pleasing Sound] Carbon fiber tailpiece with 4 detachable fine tuners can tune precisely. Robust durable steel strings add richness and power to the sound. Brazilwood bow with unbleached natural horsehair pulls out the best-balanced sound &#x1F3BB [More Size Options for Everyone] Picking the most appropriate size is essential for a comfortable start. Offer 3 sizes for students, kids, teens, adults, beginners, and advanced players. And it is lightweight, less likely to make players' arms tired and sore to ensure long-time practice &#x1F497 [Useful Beginner Kit] Includes a hard case, extra strings, rosin, and headphone. You can get all the things you need in one purchase, it is cost-effective and time-saving. We provide a 1-year warranty, aiming to provide customers with high-quality products and sincere service. If you have any problems, just feel free to contact us. We will definitely give you a satisfactory solution",
#         "store": "Vangoa",
#         "sub_categories": "Categories: Musical Instruments, Band & Orchestra, Orchestral Strings, Violins, Electric Violins",
#         "color": "Black",
#         "details": "{'Item Weight': '5.29 pounds', 'Package Dimensions': '32.8 x 13 x 5.7 inches', 'Item model number': '4354272141', 'Best Sellers Rank': {'Musical Instruments': 4412, 'Electric Violins': 1}, 'Is Discontinued By Manufacturer': 'No', 'Date First Available': 'June 22, 2017', 'Back Material': 'Ebony', 'Body Material': 'maple', 'Color Name': 'Black', 'String Material': 'Alloy Steel', 'Top Material': 'Maple', 'Neck Material Type': 'maple', 'Number of Strings': '4', 'Size': '4/4', 'Proficiency Level': 'Student', 'Brand': 'Vangoa', 'Color': 'Black', 'Top Material Type': 'Maple', 'Back Material Type': 'Ebony', 'String Material Type': 'Alloy Steel', 'Finish Type': 'Varnish', 'Instrument': 'Violin', 'Operation Mode': 'electric'}",
#         "product_title": "Product Title: Vangoa Electric Violin Full Size 4/4, Black Silent Electric Violin, Solid Wood Metallic Electric Fiddle with Ebony Fittings, Beginner Kit for Adults Teens"
#       },
#       "snippet": "Features: &#x1F3BB [Satisfying Practice & Thrilling Perform] Vangoa silent electric violin perfectly fits beginners to bring quiet moments for families, during your learning time. With headphones, you can be immersed in happy melodies, without bothering others, and progress rapidly. It's amp connectable to play louder, showing your musical talent on stage/party &#x2728 [Quality Durable Material] P"
#     },
#     {
#       "metadata": {
#         "rating": 4.4,
#         "price": 29.0,
#         "sub_categories": "Categories: Musical Instruments, Studio Recording Equipment, Signal Processors, Direct Boxes",
#         "details": "{'Item Weight': '8.5 ounces', 'Product Dimensions': '5.91 x 5.12 x 2.36 inches', 'Domestic Shipping': 'Currently, item can be shipped only within the U.S. and to APO/FPO addresses. For APO/FPO shipments, please check with the manufacturer regarding warranty and support issues.', 'International Shipping': 'This item can be shipped to select countries outside of the U.S.  Learn More', 'Country of Origin': 'China', 'Item model number': 'DI20', 'Best Sellers Rank': {'Musical Instruments': 24643, 'Recording Signal Direct Boxes': 54}, 'Is Discontinued By Manufacturer': 'No', 'Date First Available': 'October 2, 2001', 'Color Name': 'Silver', 'Compatible Devices': 'Amplifiers', 'Connector Type': 'Xlr', 'Material Type': 'Others', 'Size': 'Standard', 'Brand': 'Behringer', 'Maximum Supply Voltage': '48 Volts', 'Number of Channels': '2'}",
#         "main_category": "Musical Instruments",
#         "store": "Behringer",
#         "product_title": "Product Title: Behringer ULTRA-DI DI20 Professional Active 2-Channel DI-Box/Splitter",
#         "rating_count": 985,
#         "description": "Description: BEHRINGER ULTRA-DI DI20: Professional Active 2-Channel DI-Box/Splitter: Professional and multi-purpose direct injection box for stage and studio applications: Professional and multi-purpose direct injection box for stage and studio applications: Provides impedance and signal matching for the direct connection of instruments to mixers and amplifiers: Provides impedance and signal matching for the direct connection of instruments to mixers and amplifiers: Converts 2 independent unbalanced 1/4'' TRS line inputs into 2 balanced XLR outputs: Converts 2 independent unbalanced 1/4'' TRS line inputs into 2 balanced XLR outputs: Additional Split mode (channel 1 assigns signal to both XLR outputs): Additional Split mode (channel 1 assigns signal to both XLR outputs): Ultra-flat frequency response due to servo-balanced operation: Ultra-flat frequency response due to servo-balanced operation: Internal battery automatically shuts off when phantom power is applied: Internal battery automatically shuts off when phantom power is applied: Allows direct connection to speaker outputs with up to 3,000 Watts: Allows direct connection to speaker outputs with up to 3,000 Watts: Ground Lift switch eliminates typical ground loop problems: Ground Lift switch eliminates typical ground loop problems: Input 2 usable as channel 1 Link output (additional to XLR output): Input 2 usable as channel 1 Link output (additional to XLR output): ¼\" TRS and gold-plated XLR connectors: ¼\" TRS and gold-plated XLR connectors: Ultra-rugged, road-suitable metal case: Ultra-rugged, road-suitable metal case: High-quality components and exceptionally rugged construction ensure long life: High-quality components and exceptionally rugged construction ensure long life: Conceived and designed by BEHRINGER Germany: Conceived and designed by BEHRINGER Germany: The ULTRA-DI DI20 is a one-of-a-kind DI (direct injection) box that can convert up to two separate unbalanced 1/4\" TRS lines into two balanced XLR outputs, or function as a signal splitter. Electric guitarists, keyboardists and bassists will love the flexibility this incredible box provides.: Mono, Stereo or Double the Amps: By flipping a switch, you can use the DI20 as a launching pad for two separate mono signals, a stereo signal, or a split-signal feeding two separate amps. The DI20 also features a ground lift switch and the 3-position input attenuator can accommodate input levels of up to +48 dBu. This handy built-in attenuator allows you to connect to your amplifier's speaker outputs, even amps rated as high as 3,000 Watts. You can power the DI20 with either a 9 V battery or your mixer's phantom power supply (+18 to +48 V DC). The whole package is wrapped in an ultra compact, road-suitable and rugged metal housing.: Be Direct: If you're a working musician who demands uncompromising functionality and durability, the ULTRA-DI DI20 will astound you - and so will its very affordable price tag. See what the DI20 can do for your sound today at your nearest BEHRINGER dealer.",
#         "color": "Not Specified",
#         "features": "Features: Professional and multi-purpose direct injection box for stage and studio applications Provides impedance and signal matching for the direct connection of instruments to mixers and amplifiers Converts 2 independent unbalanced 1/4'' TRS line inputs into 2 balanced XLR outputs Additional Split mode (channel 1 assigns signal to both XLR outputs) Ultra-flat frequency response due to servo-balanced operation",
#         "product_id": "B000CCSWQA"
#       },
#       "snippet": "Direct: If you're a working musician who demands uncompromising functionality and durability, the ULTRA-DI DI20 will astound you - and so will its very affordable price tag. See what the DI20 can do for your sound today at your nearest BEHRINGER dealer."
#     },
#     {
#       "metadata": {
#         "product_title": "Product Title: Meinl Cymbals HCS 14\" Crash Cymbal for Drum Set — Made in Germany — Traditional Medium Brass, 2-Year Warranty, (HCS14C)",
#         "color": "Brass",
#         "details": "{'Item Weight': '1.57 pounds', 'Product Dimensions': '14 x 1 x 14 inches', 'Item model number': 'HCS14C', 'Best Sellers Rank': {'Musical Instruments': 24682, 'Crash Cymbals': 33}, 'Is Discontinued By Manufacturer': 'No', 'Date First Available': 'July 14, 2008', 'Body Material': 'Brass', 'Color Name': 'Brass', 'Material Type': 'Brass', 'Size': '14\" Crash', 'Color': 'Brass', 'Brand': 'Meinl Cymbals', 'Material': 'Brass', 'Model Name': 'MEINL', 'Item Dimensions LxWxH': '14 x 1 x 14 inches'}",
#         "rating": 4.5,
#         "price": 49.99,
#         "main_category": "Musical Instruments",
#         "features": "Features: MAJOR UPGRADE FROM \"STOCK\" STARTER CYMBALS: these are not those distractingly cheap, flimsy prop cymbals that come with most drum sets; Meinl HCS cymbals have impressive sound and sturdy feel geared toward beginner/intermediate players WHY IT MATTERS: playing HCS cymbals will sound more like what you hear in actual songs, making the drums even more fun to play; plus, they aren't going to fall apart, dent, or bend after a few uses like stock cymbals WHAT'S IN THE BOX: includes one 14\" crash cymbal; this crash cuts through music with a clear attack and balanced sustain that doesn't linger too long; it delivers exceptional punch to accent the beat, and it blends with all other HCS crash sizes DRIVING THE SOUND: made in Germany with MS63 brass alloy for a clean, bright, and crisp tone; substantial thickness with well-formed surface grooves and hammer marks give you a defined sound without clangy or ear-piercing overtones CATCH UP QUICK: HCS exceeds expectations because Meinl brings experience crafting cymbals since 1951; we make HCS and other lines in our German factory, and our top-of-the-line professional Byzance cymbals are hand hammered in Turkey from cast B20 bronze ZOOM IN: the surface shimmers and shines under light, which is a bonus if you like your kit to look beautiful; HCS cymbals also feature the same logo treatment as our professional lines, including a small laser engraved logo and serial number OF NOTE: you can find any sound in the seemingly never-ending selection of cymbal types in the HCS line; all essentials in multiple sizes are covered along with effects cymbals that let you expand your sound with variety THE BOTTOM LINE: this is a German made, top-quality entry level cymbal that resembles more high-end models with its crisp, bright tone and musical feel; it has a long lifespan, even for hard hitters, and fits any musical style",
#         "description": "Description: These Brass alloy models sound and look great, and let you get into playing Meinl at very realistic prices. The HCS series from Meinl cymbals is designed to offer all of the cymbal types and sizes normally found in professional lines to beginners, in order to deliver the same sound options a working drummer may look for. The HCS 14\" Crash provides a warm crash sound with a shorter sustain that is perfect for quick crash accents. Bigger than a splash, but not quite as heavy as the larger models, The 14\" Size is the perfect middle ground to blend colorful cymbal accents into your playing. Meinl HCS cymbals are recommended for any style of music a beginner may be getting into while exploring their sound.",
#         "product_id": "B09X6FV4FK",
#         "rating_count": 696,
#         "store": "Meinl Cymbals",
#         "sub_categories": "Categories: Musical Instruments, Drums & Percussion, Drum Sets & Set Components, Cymbals, Crash"
#       },
#       "snippet": "Features: MAJOR UPGRADE FROM \"STOCK\" STARTER CYMBALS: these are not those distractingly cheap, flimsy prop cymbals that come with most drum sets; Meinl HCS cymbals have impressive sound and sturdy feel geared toward beginner/intermediate players WHY IT MATTERS: playing HCS cymbals will sound more like what you hear in actual songs, making the drums even more fun to play; plus, they aren't going to"
#     }
#   ]
# }

# %%
print(f"📚 Retrieved chunks: {len(result2['retrieved'])}")

for i, chunk in enumerate(result2["retrieved"], start=1):
    print(f"\n--- Chunk {i} ---")
    print("Metadata:", chunk["metadata"])
    print("Snippet:", chunk["snippet"][:250], "...")
# Out:
# 📚 Retrieved chunks: 4
#
# --- Chunk 1 ---
# Metadata: {'product_title': 'Product Title: co2CREA Hard Case replacement for AKAI Professional MPK Mini MK3 / MPK Mini Play MK3 25 Key USB MIDI Keyboard Controller', 'product_id': 'B09ZNNYMQ9', 'color': 'All Black Case', 'features': 'Features: co2CREA hard travel case replacement for Akai professional mpk mini mk3 midi keyboard sound board controller or Akai mpk mini play mk3 25 key usb midi keyboard controller. Hard EVA shell case is shockproof dustproof and water resistance, protect your Akai mpk mini mk3 mini keyboard piano Akai midi keyboard beat machine from drops, scratches, bumps, splash, and dust. This Akai mpk mini mk3 mini piano synthesizer keyboard protection case perfect for your Akai mpk mini mk3 midi keyboard sound board mini piano keyboard or Akai mpk mini play mk3 25 key usb midi keyboard computer recording midi controllers. And this Akai mpk mini mk2 mini midi keyboard case has more space to accommodate the Akai professional mpk mini mk3 controlador midi piano and more accessories. co2CREA hard Akai mini mk3 midi controller keyboard protective case is a build-in super quality lining reflects superior taste and ensures a long-lasting performance, the soft anti static lining can protect your Akai professional mpk mini mk3 midi drum pad music instruments beat maker machine musical keyboard from bumps dents and scratches. This Akai mpk mini mk3 mini DJ controller case has a comfortable hand strap, so that the Akai professional mpk mini mk3 drum machine beat maker music pad electronic music equipment can travel with you easily. and this Akai mini mk3 sound board mini keyboard piano case has a special and strong zipper, which can bring you a better using experience. For sale is CASE ONLY! (Akai mpk mini midi keyboard and midi piano keyboard for computer accessories are not included)', 'rating': 4.7, 'price': 29.99, 'store': 'co2CREA', 'description': 'Description: ', 'rating_count': 1209, 'main_category': 'Musical Instruments', 'details': "{'Item Weight': '15.5 ounces', 'Package Dimensions': '13.74 x 10.03 x 2.48 inches', 'Item model number': 'CA-0814-1162', 'Best Sellers Rank': {'Musical Instruments': 5710, 'Computer Recording MIDI Controllers': 39}, 'Date First Available': 'August 14, 2020', 'Color Name': 'All Black Case', 'Connector Type': 'USB', 'Hardware Interface': 'USB', 'Material Type': 'Eva', 'Musical Style': 'Electronic', 'Brand': 'co2CREA', 'Connectivity Technology': 'USB', 'Special Feature': 'Keyboard Controller', 'Color': 'All Black Case', 'Style': 'MPK Mini MK3'}", 'sub_categories': 'Categories: Musical Instruments, Studio Recording Equipment, Computer Recording, MIDI Controllers'}
# Snippet: a special and strong zipper, which can bring you a better using experience. For sale is CASE ONLY! (Akai mpk mini midi keyboard and midi piano keyboard for computer accessories are not included) ...
#
# --- Chunk 2 ---
# Metadata: {'rating': 4.0, 'product_id': 'B0B1T7BM9X', 'description': 'Description: ', 'price': 129.95, 'rating_count': 626, 'main_category': 'Musical Instruments', 'features': "Features: &#x1F3BB [Satisfying Practice & Thrilling Perform] Vangoa silent electric violin perfectly fits beginners to bring quiet moments for families, during your learning time. With headphones, you can be immersed in happy melodies, without bothering others, and progress rapidly. It's amp connectable to play louder, showing your musical talent on stage/party &#x2728 [Quality Durable Material] Premium Solid maple wood body in black metallic varnish produces a crisper, more resonant, and brighter sound. Selected ebony fretboard ensures smooth playing while solid maple head, pegs, and chin rest are durable for a long period of practice &#xF3B6 [Pleasing Sound] Carbon fiber tailpiece with 4 detachable fine tuners can tune precisely. Robust durable steel strings add richness and power to the sound. Brazilwood bow with unbleached natural horsehair pulls out the best-balanced sound &#x1F3BB [More Size Options for Everyone] Picking the most appropriate size is essential for a comfortable start. Offer 3 sizes for students, kids, teens, adults, beginners, and advanced players. And it is lightweight, less likely to make players' arms tired and sore to ensure long-time practice &#x1F497 [Useful Beginner Kit] Includes a hard case, extra strings, rosin, and headphone. You can get all the things you need in one purchase, it is cost-effective and time-saving. We provide a 1-year warranty, aiming to provide customers with high-quality products and sincere service. If you have any problems, just feel free to contact us. We will definitely give you a satisfactory solution", 'store': 'Vangoa', 'sub_categories': 'Categories: Musical Instruments, Band & Orchestra, Orchestral Strings, Violins, Electric Violins', 'color': 'Black', 'details': "{'Item Weight': '5.29 pounds', 'Package Dimensions': '32.8 x 13 x 5.7 inches', 'Item model number': '4354272141', 'Best Sellers Rank': {'Musical Instruments': 4412, 'Electric Violins': 1}, 'Is Discontinued By Manufacturer': 'No', 'Date First Available': 'June 22, 2017', 'Back Material': 'Ebony', 'Body Material': 'maple', 'Color Name': 'Black', 'String Material': 'Alloy Steel', 'Top Material': 'Maple', 'Neck Material Type': 'maple', 'Number of Strings': '4', 'Size': '4/4', 'Proficiency Level': 'Student', 'Brand': 'Vangoa', 'Color': 'Black', 'Top Material Type': 'Maple', 'Back Material Type': 'Ebony', 'String Material Type': 'Alloy Steel', 'Finish Type': 'Varnish', 'Instrument': 'Violin', 'Operation Mode': 'electric'}", 'product_title': 'Product Title: Vangoa Electric Violin Full Size 4/4, Black Silent Electric Violin, Solid Wood Metallic Electric Fiddle with Ebony Fittings, Beginner Kit for Adults Teens'}
# Snippet: Features: &#x1F3BB [Satisfying Practice & Thrilling Perform] Vangoa silent electric violin perfectly fits beginners to bring quiet moments for families, during your learning time. With headphones, you can be immersed in happy melodies, without bother ...
#
# --- Chunk 3 ---
# Metadata: {'rating': 4.4, 'price': 29.0, 'sub_categories': 'Categories: Musical Instruments, Studio Recording Equipment, Signal Processors, Direct Boxes', 'details': "{'Item Weight': '8.5 ounces', 'Product Dimensions': '5.91 x 5.12 x 2.36 inches', 'Domestic Shipping': 'Currently, item can be shipped only within the U.S. and to APO/FPO addresses. For APO/FPO shipments, please check with the manufacturer regarding warranty and support issues.', 'International Shipping': 'This item can be shipped to select countries outside of the U.S.  Learn More', 'Country of Origin': 'China', 'Item model number': 'DI20', 'Best Sellers Rank': {'Musical Instruments': 24643, 'Recording Signal Direct Boxes': 54}, 'Is Discontinued By Manufacturer': 'No', 'Date First Available': 'October 2, 2001', 'Color Name': 'Silver', 'Compatible Devices': 'Amplifiers', 'Connector Type': 'Xlr', 'Material Type': 'Others', 'Size': 'Standard', 'Brand': 'Behringer', 'Maximum Supply Voltage': '48 Volts', 'Number of Channels': '2'}", 'main_category': 'Musical Instruments', 'store': 'Behringer', 'product_title': 'Product Title: Behringer ULTRA-DI DI20 Professional Active 2-Channel DI-Box/Splitter', 'rating_count': 985, 'description': 'Description: BEHRINGER ULTRA-DI DI20: Professional Active 2-Channel DI-Box/Splitter: Professional and multi-purpose direct injection box for stage and studio applications: Professional and multi-purpose direct injection box for stage and studio applications: Provides impedance and signal matching for the direct connection of instruments to mixers and amplifiers: Provides impedance and signal matching for the direct connection of instruments to mixers and amplifiers: Converts 2 independent unbalanced 1/4\'\' TRS line inputs into 2 balanced XLR outputs: Converts 2 independent unbalanced 1/4\'\' TRS line inputs into 2 balanced XLR outputs: Additional Split mode (channel 1 assigns signal to both XLR outputs): Additional Split mode (channel 1 assigns signal to both XLR outputs): Ultra-flat frequency response due to servo-balanced operation: Ultra-flat frequency response due to servo-balanced operation: Internal battery automatically shuts off when phantom power is applied: Internal battery automatically shuts off when phantom power is applied: Allows direct connection to speaker outputs with up to 3,000 Watts: Allows direct connection to speaker outputs with up to 3,000 Watts: Ground Lift switch eliminates typical ground loop problems: Ground Lift switch eliminates typical ground loop problems: Input 2 usable as channel 1 Link output (additional to XLR output): Input 2 usable as channel 1 Link output (additional to XLR output): ¼" TRS and gold-plated XLR connectors: ¼" TRS and gold-plated XLR connectors: Ultra-rugged, road-suitable metal case: Ultra-rugged, road-suitable metal case: High-quality components and exceptionally rugged construction ensure long life: High-quality components and exceptionally rugged construction ensure long life: Conceived and designed by BEHRINGER Germany: Conceived and designed by BEHRINGER Germany: The ULTRA-DI DI20 is a one-of-a-kind DI (direct injection) box that can convert up to two separate unbalanced 1/4" TRS lines into two balanced XLR outputs, or function as a signal splitter. Electric guitarists, keyboardists and bassists will love the flexibility this incredible box provides.: Mono, Stereo or Double the Amps: By flipping a switch, you can use the DI20 as a launching pad for two separate mono signals, a stereo signal, or a split-signal feeding two separate amps. The DI20 also features a ground lift switch and the 3-position input attenuator can accommodate input levels of up to +48 dBu. This handy built-in attenuator allows you to connect to your amplifier\'s speaker outputs, even amps rated as high as 3,000 Watts. You can power the DI20 with either a 9 V battery or your mixer\'s phantom power supply (+18 to +48 V DC). The whole package is wrapped in an ultra compact, road-suitable and rugged metal housing ...
# Snippet: Direct: If you're a working musician who demands uncompromising functionality and durability, the ULTRA-DI DI20 will astound you - and so will its very affordable price tag. See what the DI20 can do for your sound today at your nearest BEHRINGER deal ...
#
# --- Chunk 4 ---
# Metadata: {'product_title': 'Product Title: Meinl Cymbals HCS 14" Crash Cymbal for Drum Set — Made in Germany — Traditional Medium Brass, 2-Year Warranty, (HCS14C)', 'color': 'Brass', 'details': '{\'Item Weight\': \'1.57 pounds\', \'Product Dimensions\': \'14 x 1 x 14 inches\', \'Item model number\': \'HCS14C\', \'Best Sellers Rank\': {\'Musical Instruments\': 24682, \'Crash Cymbals\': 33}, \'Is Discontinued By Manufacturer\': \'No\', \'Date First Available\': \'July 14, 2008\', \'Body Material\': \'Brass\', \'Color Name\': \'Brass\', \'Material Type\': \'Brass\', \'Size\': \'14" Crash\', \'Color\': \'Brass\', \'Brand\': \'Meinl Cymbals\', \'Material\': \'Brass\', \'Model Name\': \'MEINL\', \'Item Dimensions LxWxH\': \'14 x 1 x 14 inches\'}', 'rating': 4.5, 'price': 49.99, 'main_category': 'Musical Instruments', 'features': 'Features: MAJOR UPGRADE FROM "STOCK" STARTER CYMBALS: these are not those distractingly cheap, flimsy prop cymbals that come with most drum sets; Meinl HCS cymbals have impressive sound and sturdy feel geared toward beginner/intermediate players WHY IT MATTERS: playing HCS cymbals will sound more like what you hear in actual songs, making the drums even more fun to play; plus, they aren\'t going to fall apart, dent, or bend after a few uses like stock cymbals WHAT\'S IN THE BOX: includes one 14" crash cymbal; this crash cuts through music with a clear attack and balanced sustain that doesn\'t linger too long; it delivers exceptional punch to accent the beat, and it blends with all other HCS crash sizes DRIVING THE SOUND: made in Germany with MS63 brass alloy for a clean, bright, and crisp tone; substantial thickness with well-formed surface grooves and hammer marks give you a defined sound without clangy or ear-piercing overtones CATCH UP QUICK: HCS exceeds expectations because Meinl brings experience crafting cymbals since 1951; we make HCS and other lines in our German factory, and our top-of-the-line professional Byzance cymbals are hand hammered in Turkey from cast B20 bronze ZOOM IN: the surface shimmers and shines under light, which is a bonus if you like your kit to look beautiful; HCS cymbals also feature the same logo treatment as our professional lines, including a small laser engraved logo and serial number OF NOTE: you can find any sound in the seemingly never-ending selection of cymbal types in the HCS line; all essentials in multiple sizes are covered along with effects cymbals that let you expand your sound with variety THE BOTTOM LINE: this is a German made, top-quality entry level cymbal that resembles more high-end models with its crisp, bright tone and musical feel; it has a long lifespan, even for hard hitters, and fits any musical style', 'description': 'Description: These Brass alloy models sound and look great, and let you get into playing Meinl at very realistic prices. The HCS series from Meinl cymbals is designed to offer all of the cymbal types and sizes normally found in professional lines to beginners, in order to deliver the same sound options a working drummer may look for. The HCS 14" Crash provides a warm crash sound with a shorter sustain that is perfect for quick crash accents. Bigger than a splash, but not quite as heavy as the larger models, The 14" Size is the perfect middle ground to blend colorful cymbal accents into your playing. Meinl HCS cymbals are recommended for any style of music a beginner may be getting into while exploring their sound.', 'product_id': 'B09X6FV4FK', 'rating_count': 696, 'store': 'Meinl Cymbals', 'sub_categories': 'Categories: Musical Instruments, Drums & Percussion, Drum Sets & Set Components, Cymbals, Crash'}
# Snippet: Features: MAJOR UPGRADE FROM "STOCK" STARTER CYMBALS: these are not those distractingly cheap, flimsy prop cymbals that come with most drum sets; Meinl HCS cymbals have impressive sound and sturdy feel geared toward beginner/intermediate players WHY  ...

# %%
def chat_once(session_id, user_id, user_input, history=None):
    if history is None:
        history = [{"role": "user", "content": user_input}]
    else:
        history = history + [{"role": "user", "content": user_input}]
    
    # simulate backend request
    req = {
        "session_id": session_id,
        "user_id": user_id,
        "messages": history,
    }
    
    res = run_chat(req["messages"])
    
    print("\n🗣️ User:", user_input)
    print("🤖 Bot:", res["answer"])
    return res["messages"]

# Example usage:
history = chat_once("S999", "UABC", "What is a good smartphone for photography?")
history = chat_once("S999", "UABC", "And something cheaper?", history)
history = chat_once("S999", "UABC", "Which one has best battery?", history)
